# %%
from __future__ import print_function

import sys
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

from keras.layers import Input, Embedding, LSTM, TimeDistributed, Dense
from keras.models import Model, load_model

# To import 'katakana' from relative path
sys.path.append(os.path.abspath(os.path.join('..')))
from katakana import encoding

INPUT_LENGTH = 22
OUTPUT_LENGTH = 22
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Data pre-processing

# %%
with open('../data/dataset_random.txt', 'r', encoding='utf-8') as f:
    lines = f.read().split('\n')

data_input=[]
data_output=[]
        
for line in lines:
    input_text, target_text = line.split(' ')
    #if(len(input_text)>20 and len(target_text)>20):
     #   print(input_text+" "+target_text)
    data_input.append(input_text)
    data_output.append(target_text)
    
print(data_input[1],data_output[1])
# Out:
# রাজ্যগুলোর রাজ্য

# %%
#data = pd.read_csv('../data/joined_titles.csv', header=None)
#data = data.sample(frac=1, random_state=0)

########################data_input = [s.decode('utf-8').lower() for s in data[0]]
########################data_output = [s.decode('utf-8') for s in data[1]]

#data_input = [s.lower() for s in data[0]]
#data_output = [s for s in data[1]]

#print(data_input[0], data_output[0])
#print(data_input[5], data_output[5])


data_size = len(data_input)

# We will use the first 0-60th %-tile (60%) of data for the training
training_input  = data_input[int(data_size*0/100):int(data_size*80/100)]
training_output = data_output[int(data_size*0/100):int(data_size*80/100)]

# We will use the first 60-70th %-tile (10%) of data for the training
validation_input = data_input[int(data_size*80/100):int(data_size*100/100)]
validation_output = data_output[int(data_size*80/100):int(data_size*100/100)]

print('training size', len(training_input))
print('validation size', len(validation_input))
# Out:
# training size 26011
# validation size 6503

# %% [markdown]
# ### Transform data into Numpy arrays
#
# We transform the sequences of characters into sequences of integer IDs. This will be done by using pre-written functions in `encoding` module.
# - First, `encoding.build_characters_encoding` will build encoding/decoding dictionary from the data.
# - Then, `encoding.transform` will transform the data into numpy array.
#
# Check [the previous notebook](./Writing Katakana using Sequence-to-Sequence in Keras) for the details about the transformation.

# %%
input_encoding, input_decoding, input_dict_size = encoding.build_characters_encoding(data_input)
output_encoding, output_decoding, output_dict_size = encoding.build_characters_encoding(data_output)

print('Input character dict size:', input_dict_size)
print('Output character dict size:', output_dict_size)

encoded_training_input = encoding.transform(
    input_encoding, training_input, vector_size=INPUT_LENGTH)
encoded_training_output = encoding.transform(
    output_encoding, training_output, vector_size=OUTPUT_LENGTH)

print('encoded_training_input', encoded_training_input.shape)
print('encoded_training_output', encoded_training_output.shape)

encoded_validation_input = encoding.transform(
    input_encoding, validation_input, vector_size=INPUT_LENGTH)
encoded_validation_output = encoding.transform(
    output_encoding, validation_output, vector_size=OUTPUT_LENGTH)

print('encoded_validation_input', encoded_validation_input.shape)
print('encoded_validation_output', encoded_validation_output.shape)
# Out:
# Input character dict size: 79
# Output character dict size: 78
# encoded_training_input (26011, 22)
# encoded_training_output (26011, 22)
# encoded_validation_input (6503, 22)
# encoded_validation_output (6503, 22)

# %% [markdown]
# # Sequence-to-Sequence in Keras

# %%
encoder_input = Input(shape=(INPUT_LENGTH,))
decoder_input = Input(shape=(OUTPUT_LENGTH,))

# %% [markdown]
# ### Encoder / Decoder

# %%
from keras.layers import SimpleRNN

encoder = Embedding(input_dict_size, 64, input_length=INPUT_LENGTH, mask_zero=True)(encoder_input)
encoder = LSTM(64, return_sequences=True, unroll=True)(encoder)
encoder_last = encoder[:,-1,:]

print('encoder', encoder)
print('encoder_last', encoder_last)

decoder = Embedding(output_dict_size, 64, input_length=OUTPUT_LENGTH, mask_zero=True)(decoder_input)
decoder = LSTM(64, return_sequences=True, unroll=True)(decoder, initial_state=[encoder_last, encoder_last])

print('decoder', decoder)
# Out:
# encoder Tensor("lstm_1/transpose_2:0", shape=(?, 22, 64), dtype=float32)
# encoder_last Tensor("strided_slice:0", shape=(?, 64), dtype=float32)
# decoder Tensor("lstm_2/transpose_2:0", shape=(?, 22, 64), dtype=float32)

# %% [markdown]
# ### Attention Mechanism
#
# Reference:
# [Effective Approaches to Attention-based Neural Machine Translation](https://arxiv.org/pdf/1508.04025.pdf)'s
# **Global Attention** with **Dot**-based scoring function (Section 3, 3.1)

# %%
from keras.layers import Activation, dot, concatenate

# Equation (7) with 'dot' score from Section 3.1 in the paper.
# Note that we reuse Softmax-activation layer instead of writing tensor calculation
attention = dot([decoder, encoder], axes=[2, 2])
attention = Activation('softmax', name='attention')(attention)
print('attention', attention)

context = dot([attention, encoder], axes=[2,1])
print('context', context)

decoder_combined_context = concatenate([context, decoder])
print('decoder_combined_context', decoder_combined_context)

# Has another weight + tanh layer as described in equation (5) of the paper
output = TimeDistributed(Dense(64, activation="tanh"))(decoder_combined_context)
output = TimeDistributed(Dense(output_dict_size, activation="softmax"))(output)
print('output', output)
# Out:
# attention Tensor("attention/truediv:0", shape=(?, 22, 22), dtype=float32)
# context Tensor("dot_2/MatMul:0", shape=(?, 22, 64), dtype=float32)
# decoder_combined_context Tensor("concatenate_1/concat:0", shape=(?, 22, 128), dtype=float32)
# output Tensor("time_distributed_2/Reshape_1:0", shape=(?, 22, 78), dtype=float32)

# %%
model = Model(inputs=[encoder_input, decoder_input], outputs=[output])
model.compile(optimizer='adam', loss='categorical_crossentropy',metrics=['accuracy'])

# %% [markdown]
# ## Training the model

# %%
training_encoder_input = encoded_training_input
training_decoder_input = np.zeros_like(encoded_training_output)
training_decoder_input[:, 1:] = encoded_training_output[:,:-1]
training_decoder_input[:, 0] = encoding.CHAR_CODE_START
training_decoder_output = np.eye(output_dict_size)[encoded_training_output.astype('int')]

validation_encoder_input = encoded_validation_input
validation_decoder_input = np.zeros_like(encoded_validation_output)
validation_decoder_input[:, 1:] = encoded_validation_output[:,:-1]
validation_decoder_input[:, 0] = encoding.CHAR_CODE_START
validation_decoder_output = np.eye(output_dict_size)[encoded_validation_output.astype('int')]

# %%
if os.path.isfile('model.h5'):
    model = load_model('model.h5')
else:
    history=model.fit(x=[training_encoder_input, training_decoder_input], y=[training_decoder_output],
          validation_data=([validation_encoder_input, validation_decoder_input], [validation_decoder_output]),
          verbose=2, batch_size=64, epochs=15) #epochs=30)
                      
history=model.fit(x=[training_encoder_input, training_decoder_input], y=[training_decoder_output],
          validation_data=([validation_encoder_input, validation_decoder_input], [validation_decoder_output]),
          verbose=2, batch_size=64, epochs=5)

model.save('model.h5')
# Out:
# Train on 26011 samples, validate on 6503 samples
# Epoch 1/15
#  - 79s - loss: 2.8625 - acc: 0.2759 - val_loss: 2.3274 - val_acc: 0.3817
# Epoch 2/15
#  - 45s - loss: 2.0012 - acc: 0.4605 - val_loss: 1.7256 - val_acc: 0.5273
# Epoch 3/15
#  - 45s - loss: 1.4330 - acc: 0.6003 - val_loss: 1.2110 - val_acc: 0.6581
# Epoch 4/15
#  - 45s - loss: 1.0379 - acc: 0.7051 - val_loss: 0.8878 - val_acc: 0.7467
# Epoch 5/15
#  - 45s - loss: 0.7552 - acc: 0.7856 - val_loss: 0.6315 - val_acc: 0.8200
# Epoch 6/15
#  - 45s - loss: 0.5367 - acc: 0.8495 - val_loss: 0.4718 - val_acc: 0.8680
# Epoch 7/15
#  - 45s - loss: 0.3845 - acc: 0.8929 - val_loss: 0.3416 - val_acc: 0.9036
# Epoch 8/15
#  - 45s - loss: 0.2789 - acc: 0.9232 - val_loss: 0.2336 - val_acc: 0.9355
# Epoch 9/15
#  - 45s - loss: 0.2097 - acc: 0.9415 - val_loss: 0.1752 - val_acc: 0.9533
# Epoch 10/15
#  - 45s - loss: 0.1579 - acc: 0.9561 - val_loss: 0.1567 - val_acc: 0.9551
# Epoch 11/15
#  - 45s - loss: 0.1254 - acc: 0.9648 - val_loss: 0.1249 - val_acc: 0.9639
# Epoch 12/15
#  - 45s - loss: 0.1037 - acc: 0.9699 - val_loss: 0.1016 - val_acc: 0.9701
# Epoch 13/15
#  - 45s - loss: 0.0863 - acc: 0.9751 - val_loss: 0.0812 - val_acc: 0.9761
# Epoch 14/15
#  - 45s - loss: 0.0733 - acc: 0.9780 - val_loss: 0.0835 - val_acc: 0.9744
# Epoch 15/15
#  - 45s - loss: 0.0631 - acc: 0.9809 - val_loss: 0.0666 - val_acc: 0.9794
# Train on 26011 samples, validate on 6503 samples
# Epoch 1/5
#  - 45s - loss: 0.0578 - acc: 0.9821 - val_loss: 0.0643 - val_acc: 0.9803
# Epoch 2/5
#  - 45s - loss: 0.0502 - acc: 0.9843 - val_loss: 0.0566 - val_acc: 0.9822
# Epoch 3/5
#  - 45s - loss: 0.0467 - acc: 0.9852 - val_loss: 0.0514 - val_acc: 0.9837
# Epoch 4/5
#  - 45s - loss: 0.0429 - acc: 0.9862 - val_loss: 0.0538 - val_acc: 0.9825
# Epoch 5/5
#  - 45s - loss: 0.0401 - acc: 0.9869 - val_loss: 0.0478 - val_acc: 0.9840
# C:\Users\RANA_CSE\Anaconda3\lib\site-packages\keras\engine\topology.py:2361: UserWarning: Layer lstm_2 was passed non-serializable keyword arguments: {'initial_state': [<tf.Tensor 'strided_slice:0' shape=(?, 64) dtype=float32>, <tf.Tensor 'strided_slice:0' shape=(?, 64) dtype=float32>]}. They will not be included in the serialized model (and thus will be missing at deserialization time).
#   str(node.arguments) + '. They will not be included '

# %% [markdown]
# ### Testing the model

# %%
def generate(text):
    encoder_input = encoding.transform(input_encoding, [text.lower()], 22)
    decoder_input = np.zeros(shape=(len(encoder_input), OUTPUT_LENGTH))
    decoder_input[:,0] = encoding.CHAR_CODE_START
    for i in range(1, OUTPUT_LENGTH):
        output = model.predict([encoder_input, decoder_input]).argmax(axis=2)
        decoder_input[:,i] = output[:,i]
    return decoder_input[:,1:]

def decode(decoding, sequence):
    text = ''
    for i in sequence:
        if i == 0:
            break
        text += output_decoding[i]
    return text

def to_stem(text):
    decoder_output = generate(text)
    return decode(output_decoding, decoder_output[0])


common_american_names = ['James', 'John', 'Robert', 'Mary', 'Patricia', 'Linda']

common_american_names=['Unschooling',
'Lovosice',
'Milch',
'Juva',
'Brembilla',
'Sa Pa',
'Brumano',
'Brusaporto',
'Deventer',
'Enschede']

common_american_names=['এই বটের আশ্রয়ে',
'ঐ বটের ছায়ায়',
'বটে! বটে! বটে!',
'বিচিত্র বটে! লাল',
'১২ই মে ২০২৫',
'আজ মে মাস',
'হাসিতে মেতে উঠল' ]

#for name in common_american_names:
 #   print(name, to_katakana(name))

# %%
#print(to_katakana('সাদা লাল নীল'))
#print(to_katakana('Peter Parker'))
#print(to_katakana('Jonny Snow'))

with open('../data/stemmer_dataset.txt', 'r', encoding='utf-8') as f:
    lines = f.read().split('\n')

    count=0
for line in lines[30005: 35005]:
    test_input_text, test_target_text = line.split(' ')
    test_output_text=to_stem(test_input_text)
    print(test_input_text+"------"+test_output_text)
    if(test_output_text==test_target_text):
        count+=1
        
print((count*100)/5000)
# Out:
# থাইয়ের------থাইয়ে
# বার্সেলোনারই------বার্সেলোনা
# লিগনিনের------লিগনিন
# কুর্মীর------কুর্মী
# মেশিনগুলো------মেশিন
# ফেরারির------ফেরারি
# অ্যাভাটারের------অ্যাভাটার
# চাটাইগুলো------চাটাই
# কমিটিরই------কমিটি
# আত্মীয়স্বজনেরা------আত্মীয়স্বজনি
# পদকে------পদ
# তাহেরকে------তাহের
# উইকেটশিকারির------উইকেটশিকি
# বাঁহাতিতে------বাঁহাতি
# এআরএফের------এআরএফ
# স্বাচিপের------স্বাচিপ
# পরোপকারের------পরোপকার
# স্ট্রাইকারদের------স্ট্রাইকার
# নুনিয়াকে------নুনিয়া
# ব্যক্তিস্বাধীনতার------ব্যক্তিস্বাধীনতা
# আইনগুলোও------আইন
# কারওয়ানবাজারে------কারওয়ানবাজার
# কুর্মীও------কুর্মী
# প্রেখটের------প্রেখট
# টুইঙ্কলও------টুইঙ্কল
# মুসলমানে------মুসলমান
# আইনগুলোই------আইন
# সংগীতশিল্পীকে------সংগীতশিল্পী
# টিকিটের------টিকিট
# সৃজনের------সৃজন
# এয়ারপোর্টে------এয়ারপোর্ট
# রুচির------রুচি
# প্রভাতির------প্রভাতি
# ইনভয়েসে------ইনভয়েস
# ব্যাকরণটি------ব্যাকরণ
# অরুপার------অরুপা
# সিডনিতে------সিডনি
# ইলাস্ট্রেশনটা------ইলাস্ট্রেশন
# প্রভাতীর------প্রভাতী
# বার্সেলোনাকে------বার্সেলোনা
# পদটি------পদ
# ইএসপিএনকে------ইএসপিএন
# শ্রেণীভুক্তরা------শ্রেণীভুক্ত
# সিরার------সিরা
# মন্দিরাকে------মন্দিরা
# এয়ারওয়েজকে------এয়ারওয়েজ
# আলাপচারিতাকে------আলাপচারিতা
# দরপতনের------দরপতন
# হানসেনের------হানসেন
# বোর্ডেই------বোর্ড
# বোর্ডেও------বোর্ড
# যৌনপল্লির------যৌনপল্লি
# সঞ্চয়পত্রে------সঞ্চয়পত্র
# টেংরাটিলায়------টেংরাটিলা
# মরিসনের------মরিসন
# অভিজ্ঞতায়------অভিজ্ঞতা
# ব্যবহারজীবীও------ব্যবহারজীবী
# পোড়ানোকে------পোড়ানো
# উর্দুই------উর্দুই
# মোশারফকে------মোশারফ
# মনোহরের------মনোহর
# পৌত্তলিকদের------পৌত্তলিক
# সঞ্জয়ও------সঞ্জয়
# নম্বরপত্রই------নম্বরপত্র
# সাংহাইতেই------সাংহাই
# বাংলালায়নের------বাংলালায়ন
# লোকগণনার------লোকগণনা
# নভেম্বরেরই------নভেম্বর
# ভাবনাকে------ভাবনা
# সঞ্জয়ই------সঞ্জয়
# ক্ষীরাই------ক্ষীরা
# লালনপালনের------লালনপালন
# বলশেভিকদের------বলশেভিক
# ট্যাবের------ট্যাব
# ভালোয়------ভালোয়
# কমিটিতে------কমিটি
# ভালোর------ভালো
# ভিত্তিপ্রস্তরও------ভিত্তিপ্রস্তর
# স্বস্তিতেই------স্বস্তি
# ভালোও------ভালো
# পেটার------পেটা
# গুণীজনের------গুণীজন
# টার্নওভারের------টার্নওভার
# সমৃদ্ধকরণের------সমৃদ্ধকরণ
# জননীকে------জননী
# প্রত্নতত্ত্ববিদেরা------প্রত্নতত্ত্ববিব
# অভিজ্ঞতার------অভিজ্ঞতা
# বিষ্ঠার------বিষ্ঠা
# খরগোশছানাটিকে------খরগোশছানা
# পিতৃত্বের------পিতৃত্ব
# বউটির------বউটি
# পেটির------পেটি
# অভিজ্ঞতাও------অভিজ্ঞতা
# সমবায়ই------সমবা
# অভিজ্ঞতাই------অভিজ্ঞতা
# কুয়েতিকেই------কুয়েতি
# পদেই------পদে
# দৃশ্যগুলো------দৃশ্য
# শামীমকে------শামীম
# ডেক্সসাতে------ডেক্সসা
# উইলটির------উইল
# পদেও------পদে
# পাত্রীকে------পাত্রী
# দেয়ালটিকে------দেয়াল
# তরুণটিকে------তরুণ
# বন্দুকই------বন্দুক
# সতর্কসংকেতটি------সতর্কসংক
# কটকায়------কটকা
# সতর্কসংকেতটা------সতর্কসংক
# নির্বাচনগুলো------নির্বাচন
# ফান্ডগুলোকে------ফান্ড
# পদের------পদের
# তালিকাতেও------তালিকা
# ব্যাকরণের------ব্যাকরণ
# ইলাস্ট্রেশনের------ইলাস্ট্রেশন
# বন্দ্যোপাধ্যায়কে------বন্দ্যোপাধ্যাল
# বমসার------বমসা
# বন্দীরা------বন্দী
# কটকার------কটকা
# জোকোভিচের------জোকোভিচ
# ভালোই------ভালো
# শেরিফের------শেরিফ
# শেষকৃত্যে------শেষকৃত্য
# হলমার্ককে------হলমার্ক
# প্রদীপের------প্রদীপ
# মহিদুলকে------মহিদুল
# নিশ্চিতের------নিশ্চিত
# সোজাসাপটাও------সোজাসাপ
# প্রেখটকে------প্রেখট
# সৃষ্টির------সৃষ্টি
# জনপদে------জনপদ
# বিএসএমএমইউতে------বিএসএমএমুই
# প্রতিষ্ঠানগুলোকেই------প্রতিষ্ঠান
# প্রতিষ্ঠানগুলোকেও------প্রতিষ্ঠান
# সৃষ্টিই------সৃষ্টি
# নিয়ন্ত্রণব্যবস্থাকে------নিয়ন্ত্রণব্যবস্থা
# কারনেবোর------কারনেবো
# এমডিপির------এমডিপি
# ঘোড়াগুলো------ঘোড়া
# সাদেককে------সাদেক
# র্যাংকসটেলের------র্যাংকসটেল
# খেলোয়াড়ে------খেলোয়াড়ে
# ইএসপিএনের------ইএসপিএন
# খেলোয়াড়ও------খেলোয়াড়
# জিজ্ঞাসার------জিজ্ঞাসা
# ক্যাসিওর------ক্যাসিও
# গুণীজনকে------গুণীজন
# পেলেগ্রিনোর------পেলেগ্রিনো
# কানাডায়ও------কানাডা
# ছাত্রসমাজকে------ছাত্রসমাজ
# সিমের------সিম
# কর্মসূচিকে------কর্মসূচি
# কামিজটায়------কামিজ
# ধৈর্যের------ধৈর্য
# খেলোয়াড়ই------খেলোয়াড়
# রেস্টুরেন্টকে------রেস্টুরেন্ট
# স্কলারিকে------স্কলারি
# বিরোধেরও------বিরোধ
# গোধূলিলগ্নের------গোধূলিলম
# লালসার------লালসা
# অ্যামচেমের------অ্যামচেম
# গ্র্যান্ডমাস্টারকে------গ্র্যান্ডমাস্ট্র
# আর্কাইভের------আর্কাইভ
# মাহমুদউল্লাহও------মাহমুদউল্লাহ
# গর্বটা------গর্ব
# মাহমুদউল্লাহর------মাহমুদউল্লাহ
# রেটটাকে------রেট
# ডিএইচএলের------ডিএইচএল
# স্বাচিবের------স্বাচিব
# মটরকে------মটরক
# আর্কাইভেই------আর্কাইভ
# কাকাউয়ের------কাকাউ
# কমিশনারকে------কমিশনার
# কাতারের------কাতার
# জালিয়ানওয়ালাবাগে------জালিয়ানায়য়ারা
# বাইপাইলে------বাইপাইল
# নির্বাচনেরই------নির্বাচন
# চেকগুলো------চেক
# কাউনাইনের------কাউনাইন
# নির্বাচনেরও------নির্বাচন
# প্রবচনের------প্রবচন
# বেল্লালের------বেল্লাল
# গাওয়াতে------গাওয়া
# প্রশিকায়------প্রশিকা
# প্রান্দেল্লির------প্রান্দেল্লি
# হ্যাকিংয়ে------হ্যাকিং
# পেটের------পেটে
# ট্যাপের------ট্যাপ
# পরস্পরের------পরস্পর
# প্রশিকার------প্রশিকা
# একাডেমীতেই------একাডেমী
# বিএসএমএমইউকে------বিএসএমএমইউ
# মাহমুদউল্লাহই------মাহমুদউল্লাহ
# মহাত্মারাও------মহাত্মা
# বাঙালিপনার------বাঙালিপনা
# পেটেই------পেটেই
# গ্লুকোজের------গ্লুকোজ
# লজ্জাতেই------লজ্জা
# সঞ্জুর------সঞ্জু
# শোকসভার------শোকসভার
# বন্দ্যোপাধ্যায়ের------বন্দ্যোপাধ্যা
# কয়লাক্ষেত্রে------কয়লাক্ষেত্র
# শোকসভায়------শোকসভা
# ডিএমকেকে------ডিএমকে
# মজনুর------মজনু
# হারারের------হারার
# আমানেরও------আমান
# স্থানও------স্থান
# ফদনারডেইলের------ফদনারডেইল
# জীবনবৃত্তান্তও------জীবনবৃত্তান্ত
# স্রোতের------স্রোত
# রোজারিওকে------রোজারিও
# ভাষাবিজ্ঞানীরা------ভাষাবিজ্ঞানী
# সংযোগদাতার------সংযোগদাতা
# গরমটা------গরম
# ঘাসপাখিও------ঘাসপাখি
# কেনটাকির------কেনটাকি
# কমালেই------কমাল
# ক্যাভিয়ারের------ক্যাভিয়ার
# ভবঘুরেদের------ভবঘুরে
# প্রাপ্তিও------প্রাপ্তি
# স্মিথের------স্মিথ
# রংধনুর------রংধনু
# সন্দেহভাজনকে------সন্দেহভাজন্
# জনসাধারণের------জনসাধারণ
# প্রাপ্তির------প্রাপ্তি
# টার্মিনালটির------টার্মিনাল
# ব্যাংকিংয়ের------ব্যাংকিং
# উপদ্রবে------উপদ্রব
# গোলাপগুলো------গোলাপ
# বন্টনের------বন্টন
# মুরগির------মুরগি
# ঋণখেলাপিরা------ঋণখেলাপি
# মৈত্রর------মৈত্র
# মুরগিই------মুরগি
# টিনশেডগুলোর------টিনশেড
# দৃশ্যটায়------দৃশ্য
# মুরগিও------মুরগি
# সেলিমের------সেলিম
# ঋতুকে------ঋতু
# ঘাসপাখির------ঘাসপাখি
# বার্নাব্যুতেই------বার্নাব্যু
# অবাঙালিরা------অবাঙালি
# বিশ্বসংগীতের------বিশ্বসংগী
# দৃশ্যটির------দৃশ্য
# আর্টেও------আর্ট
# জেলেদেরও------জেলে
# স্পিৎজাররা------স্পিৎজার
# কর্মকারের------কর্মকার
# আর্টের------আর্ট
# প্রকোষ্ঠটিতে------প্রকোষ্ঠ
# চূড়াটি------চূড়া
# নাথুয়ারডাঙ্গায়------নাথুয়ারডাঙ্গা
# সামনেও------সামন
# সামনেই------সামন
# বায়নার------বায়না
# বাদলদার------বাদলদা
# সাবেলার------সাবেলা
# স্মিথরা------স্মিথ
# বায়নাও------বায়না
# দেলওয়ারকে------দেলওয়ার
# টনকে------টনক
# ছেলেমেয়েরাও------ছেলেমেয়ে
# মৃত্যুর------মৃত্যু
# টনকও------টনক
# কক্ষগুলো------কক্ষ
# ক্লাইভের------ক্লাইভ
# এলআরআইএসের------এলআরআইসি
# লিনেকারের------লিনেকার
# জাবেলমুনে------জাবেলমুন
# অ্যান্ড্রয়েডে------অ্যান্ড্রয়েড
# নৌকাগুলাতে------নৌকাগুলা
# লিবিয়াকে------লিবিয়া
# মিলিব্যান্ডকে------মিলিব্যান্ড
# ফিলকে------ফিল
# আর্টসে------আর্টস
# ডেইজির------ডেইজি
# বিপাসকে------বিপাস
# ছাত্রনেতাকে------ছাত্রনেতা
# মাগফিরাতে------মাগফিরা
# আরিয়ানের------আরিয়ান
# মুক্তাঙ্গনের------মুক্তাঙ্গন
# পর্যবেক্ষণকে------পর্যবেক্ষণ
# মৃত্যুই------মৃত্যু
# মৃত্যুও------মৃত্যু
# ইভেন্টগুলোকে------ইভেন্ট
# বাতিটি------বাতি
# উত্পাদনক্ষমতার------উত্পাদনক্ষকতা
# হামরাকে------হামরা
# মুহূর্তটিতে------মুহূর্ত
# হারবালের------হারবাল
# হপ্তায়------হপ্তা
# শরিকেরাও------শরিকেরা
# স্বার্থলোভীরা------স্বার্থলোভী
# মক্কেলের------মক্কেল
# কম্পুতে------কম্পু
# ভিনগ্রহবাসীর------ভিনগ্রহবাসী
# রাইটার্সদের------রাইটার্স
# কিংডমের------কিংডম
# বিধবার------বিধবার
# ভোরেই------ভোর
# পর্যবেক্ষণটি------পর্যবেক্ষণ
# বাতিতে------বাতি
# লিবিয়াতে------লিবিয়া
# আলভেসকে------আলভেস
# বিনোদিনীর------বিনোদিনী
# চুইয়ের------চুই
# দৃশ্যটাও------দৃশ্য
# পশমের------পশম
# রায়গুলোর------রায়
# বিএসবিআইয়ের------বিএসবিআই
# রকমারির------রকমারি
# বিনোদিনীও------বিনোদিনী
# রাজনীতিবিদদের------রাজনীতিবিদ
# দৃশ্যটিই------দৃশ্য
# বানসালির------বানসালি
# সিএদের------সিএদ
# রাশির------রাশি
# ওয়াকিটকির------ওয়াকিটকি
# লেন্সটাও------লেন্স
# নলকূপের------নলকূপ
# পিঁপড়ার------পিঁপড়া
# শুরগঞ্জে------শুরগঞ্জ
# গাড়িচালককেও------গাড়িচালক
# উপমহাদেশেরই------উপমহাদেশ
# রাগবিটাও------রাগবি
# সিলেবাসগুলো------সিলেবাস
# টপের------টপ
# খরচটার------খরচ
# খরচটিও------খরচ
# ঘানিখানিই------ঘানিখানি
# ক্রুইফদের------ক্রুইফ
# ফিরেও------ফিরে
# স্টাডিজের------স্টাডিজ
# ওসমানের------ওসমান
# প্রাঙ্গণে------প্রাঙ্গণ
# প্রত্নতত্ত্বে------প্রত্নতত্ত্ব
# ফিরেই------ফিরে
# চিলড্রেনে------চিলড্রেন
# খুমির------খুমি
# লাহাবের------লাহাব
# গরমকে------গরম
# কানপুরের------কানপুর
# বলিভিয়ার------বলিভিয়া
# অর্ধেকটাকে------অর্ধেক
# বলিভিয়ায়------বলিভিয়া
# উৎদনের------উৎদন
# করেরহাটে------কররেহাট
# অ্যাটেনডেন্টকে------অ্যাটেনডেন্ট
# শেয়ারগুলো------শেয়ার
# কার্যকলাপকে------কার্যকলাপ
# কেমিস্ট্রির------কেমিস্ট্রি
# খরচটাই------খরচ
# নান্টুদের------নান্টু
# রেজিমেন্টকে------রেজিমেন্ট
# লিবিয়ারও------লিবিয়া
# খরচটাও------খরচ
# মহাদেশের------মহাদেশ
# বক্সগুলো------বক্স
# ফলবিক্রেতার------ফলবিক্রেতা
# ওসমানীর------ওসমানী
# রাজিবকে------রাজিব
# মহাদেশেও------মহাদেশ
# পারিতোষিকের------পারিতোষিক
# সিগন্যালের------সিগন্যাল
# প্রিসিলার------প্রিসিলা
# ওসমানীও------ওসমানী
# উদের------উদের
# তিউনেসিয়ার------তিউনেসিয়া
# প্রাঙ্গনে------প্রাঙ্গন
# বিপাশার------বিপাশা
# বাতাসই------বাতাস
# কার্যসহকারীকে------কার্যসহকারী
# মেঝেতেই------মেঝে
# মেন্ডিসের------মেন্ডিস
# মেঝেতেও------মেঝে
# রেজাল্টটা------রেজাল্ট
# তিউনেসিয়ায়------তিউনেসিয়া
# বিপাশাও------বিপাশা
# দিরাইয়ের------দিরাই
# ইমেজের------ইমেজ
# শাটলের------শাটল
# গ্লেডহিলের------গ্লেডহিল
# বাতাসে------বাতাস
# কমলাকেও------কমলা
# মার্চেন্ডাইজিংয়ের------মার্চেন্ডাইজি
# রোজারিওতে------রোজারিও
# উসকানিদাতারা------উসকানিদাতা
# তবলাকে------তবলা
# সারচার্জের------সারচার্জ
# যিশুখ্রিষ্টের------যিশুখ্রিষ্ট
# সেকান্দরের------সেকান্দর
# প্রক্টরের------প্রক্টর
# পারিজাতের------পারিজাত
# আর্টকে------আর্টক
# ক্রসিংয়ে------ক্রসিং
# ফনসেকাকে------ফনসেকা
# শীতলীকরণের------শীতলীকরণ
# শশীদে------শশীদ
# বায়দার------বায়দার
# সিগন্যালটি------সিগন্যাল
# বারলুসকোনির------বারলুসকোনি
# সাকিবুলকে------সাকিবুল
# শফিউলই------শফিউল
# বাদামতলীর------বাদামতলী
# জালিয়াতিতে------জালিয়াতি
# যুদ্ধকৌশলের------যুদ্ধকৌশল
# প্রতিটারই------প্রতিটার
# রায়পুরে------রায়পুর
# পশুপাখিরা------পশুপাখি
# ব্রংকহর্স্টকে------ব্রংকহর্স্ট
# কুটিরচরে------কুটিরচর
# শফিউলও------শফিউল
# রেজিমেন্টের------রেজিমেন্ট
# সামানিয়ার------সামানিয়ার
# প্রতিটিকে------প্রতি
# শাটলটি------শাটল
# পশারীর------পশারী
# চেচেনদের------চেচেন
# চোপড়াকে------চোপড়া
# উদ্ধারকারীরাও------উদ্ধারকারী
# ফার্মেসিতে------ফার্মেসি
# হারালেই------হারালে
# সতর্কবাণীতে------সতর্কবাণী
# ডনোভানকে------ডনোভান
# বাহনগুলোর------বাহন
# হারালেও------হারাল
# বেলজিয়ামের------বেলজিয়াম
# পুতিনের------পুতিন
# অনন্যার------অনন্যা
# যোগ্যই------যোগ্য
# রাষ্ট্রসমূহ------রাষ্ট্রস
# কারানকাকে------কারানকা
# ছেঙ্গারচরে------ছেঙ্গারচর
# কয়েকবারের------কয়েকবার
# রাজিবের------রাজিব
# কলাপাতায়------কলাপাতা
# কিটোর------কিটো
# আর্থিকপ্রতিষ্ঠানের------আর্থিকপ্রতিষ্ঠান
# এসএবিসিকে------এসএবিসি
# ভোরটি------ভোর
# রিজওয়ানও------রিজওয়ান
# সম্ভ্রমহানির------সম্ভ্রমহানি
# মেয়েশিশুকে------মেয়েশিশু
# পাটনায়------পাটনা
# পর্বতশৃঙ্গে------পর্বতশৃঙ্গ
# অ্যাঙ্গলিসর------অ্যাঙ্গলিস
# চিকিৎসাবর্জ্যে------চিকিৎসাবর্জ্য
# ভাষাবিচ্ছেদের------ভাষাবিচ্ছে
# নীতিনির্ধারককে------নীতিনির্ধারক
# পাটনার------পাটনা
# সাবধানেই------সাবধান
# প্রক্টরকে------প্রক্টর
# পর্যবেক্ষণেও------পর্যবেক্ষণ
# সাবেরের------সাবের
# প্রক্টররা------প্রক্টর
# মহাব্যবস্থাপককে------মহাব্যবস্থাপক
# ধারাবাহিকে------ধারাবাহি
# পর্যবেক্ষণের------পর্যবেক্ষণ
# বিজেএমসির------বিজেএমসি
# গণপরিবহনব্যবস্থার------গণপরিবহনব্যবস্থা
# এথনিকার------এথনিকা
# বন্ডকে------বন্ড
# গিডনের------গিডন
# হরিণও------হরিণ
# হরিণই------হরিণ
# তোরেসেরও------তোরেস
# হ্যামস্ট্রিংয়ের------হ্যামস্ট্রিং
# ফার্মেসিকে------ফার্মেসিক
# মিতাকে------মিতা
# রিমোটের------রিমোট
# বাতিলে------বাতিল
# রোমেনাদের------রোমেনা
# খানমের------খানম
# মুহূর্তটিকে------মুহূর্ত
# রিগের------রিগ
# চৌডালায়------চৌডালা
# বাতিলও------বাতিল
# তুললেও------তুলল
# বাতিলই------বাতিল
# ঘটনাতেই------ঘটনা
# আছদগঞ্জের------আছদগঞ্জ
# মান্ডায়------মান্ডা
# সাহিত্যচর্চাকে------সাহিত্যচর্চা
# কম্বলগুলো------কম্বল
# অভ্যুত্থানটির------অভ্যুত্থান
# পরিবেশকের------পরিবেশক
# আইনপ্রণেতাদের------আইনপ্রণেতা
# খাতসমূহের------খাতসমূহ
# অপেশাদারিত্বের------অপেশাদারিত্ব
# অ্যাংকরের------অ্যাংকর
# টেলিছবিটির------টেলিছবিটি
# আলভেসের------আলভেস
# সন্দেহভাজনের------সন্দেহভাজনি
# আইকনগুলো------আইকন
# বন্ডটি------বন্ড
# বিলিয়নীয়রদের------বিলিয়নীয়র
# উৎসাহের------উৎসাহ
# কাপালিকে------কাপালি
# জন্মবৃত্তান্তের------জন্মবৃত্তান্ত
# ফার্মেসিটা------ফার্মেসি
# রামগঞ্জে------রামগঞ্জ
# ঘোষণাকে------ঘোষণা
# ল্যাপটপটিতে------ল্যাপটপ
# উৎসাহেই------উৎসাহ
# খারাপকে------খারাপ
# রোগগুলোর------রোগ
# নিলুফারদের------নিলুফার
# মোনাফকে------মোনাফ
# ধর্মঘটেও------ধর্মঘট
# এপিপিরাই------এপিপি
# কৃষিজমিরও------কৃষিজমি
# ধর্মঘটের------ধর্মঘট
# আন্দোলনেও------আন্দোলন
# মান্দার------মান্দা
# অধ্যাদেশেও------অধ্যাদেশ
# এসিডদগ্ধদের------এসিডদগ্ধ
# আন্দোলনেই------আন্দোলন
# অভিযাত্রার------অভিযাত্রা
# কয়লাগুলো------কয়লা
# উনিকে------উনি
# যুবপ্রকল্পে------যুবপ্রকল্প
# অধ্যাদেশের------অধ্যাদেশ
# ইনকিউবেটরে------ইনকিউবেটর
# আন্দোলনের------আন্দোলন
# মানোন্নয়নে------মানোন্নয়ন
# আকতাররে------আকতার
# অভিযাত্রায়------অভিযাত্রা
# কারাতেকারা------কারাতেকা
# অযোগ্যতায়------অযোগ্যতা
# ওয়ানডেও------ওয়ানড
# সেকেন্ডকে------সেকেন্ড
# স্বল্পতাকে------স্বল্পতা
# অপচেষ্টার------অপচেষ্টা
# ওয়ানডেই------ওয়ানড
# কিছুও------কিছু
# রিমোটটা------রিমোট
# ভ্যারিয়েশনও------ভ্যারিয়েশন
# ড্রাগনে------ড্রাগন
# পাইলে------পাইলে
# কিছুর------কিছু
# তোতোর------তোতো
# সংবাদপত্রই------সংবাদপত্র
# অদিতিকে------অদিতি
# সংবাদপত্রও------সংবাদপত্র
# বহিস্কারের------বহিস্কার
# বর্ণমালাকে------বর্ণমালা
# পাটিবানের------পাটিবান
# জুতাটিকে------জুতা
# তথ্যমাধ্যমেও------তথ্যমাধ্যম
# ফটোসাংবাদিকদের------ফটোসাংবাদি
# কিছুই------কিছু
# কৃষিজমিতে------কৃষিজমি
# ধর্মঘটে------ধর্মঘট
# রিগটি------রিগ
# ট্রেইলটা------ট্রেইল
# ধর্মকেও------ধর্মক
# ধর্মকেই------ধর্মকে
# মোকদ্দমাটি------মোকদ্দমা
# ঘটনাস্থলে------ঘটনাস্থল
# লোকগানের------লোকগান
# উনকে------উন
# সংবাদপত্রে------সংবাদপত্র
# অ্যাটাশেকে------অ্যাটাশেক
# নিবাসে------নিবাস
# দাবাংও------দাবাং
# বর্ণবাদের------বর্ণবাদ
# উন্নয়নকাজই------উন্নয়নকাজ
# আদজারাতুর------আদজারাতু
# আন্দোলনটা------আন্দোলন
# আন্দোলনটি------আন্দোলন
# মৌয়ালকে------মৌয়াল
# পাইপে------পাইপ
# আমলকীতে------আমলকী
# আইসিইউতে------আইসিইউ
# দাঙ্গায়------দাঙ্গা
# গুয়োর------গুয়ো
# উন্নয়নকাজও------উন্নয়নকাজ
# হেকিমকে------হেকিম
# গফরগাঁয়ের------গফরগাঁ
# টনিকে------টনিক
# বক্তব্যেরও------বক্তব্য
# হেলিকপ্টারে------হেলিকপ্টার
# বিধানেরও------বিধান
# ফরোয়ার্ডকে------ফরোয়ার্ড
# রাশকে------রাশ
# সমদূরত্বের------সমদূরত্ব
# চুন্নুর------চুন্নু
# আর্তির------আর্তি
# কাওয়ানও------কাওয়ান
# আকতারের------আকতার
# তাইয়েবার------তাইয়েবার
# প্রসুতিদের------প্রসুতি
# তাইয়েবাই------তাইয়েবা
# দৈর্ঘ্যে------দৈর্ঘ্য
# পদ্মদের------পদ্ম
# ব্যবসাপ্রতিষ্ঠানে------ব্যবসাপ্রতিষ্ঠান
# উদ্যোগটাকে------উদ্যোগ
# থেরাপিতে------থেরাপি
# মূলঘরের------মূলঘর
# প্রবঞ্চনার------প্রবঞ্চনা
# কানকুনে------কানকুন
# হেলিকপ্টারও------হেলিকপ্টার
# রেজাল্টের------রেজাল্ট
# নিরীক্ষণের------নিরীক্ষণ
# রোমিংয়ের------রোমিং
# পিংকিকে------পিংকি
# পাঁচবিবির------পাঁচবিবি
# মাছকেও------মাছ
# চক্রগুলোর------চক্র
# নাবালিকার------নাবালিকা
# পুকুরটা------পুকুর
# পুকুরটি------পুকুর
# মিথ্যারই------মিথ্যা
# সোনালিচুলোকে------সোনালিচুলো
# পুনর্নিমাণের------পুনর্নিমাণ
# খুলির------খুলি
# উচ্চমূল্যের------উচ্চমূল্য
# মৌয়ালের------মৌয়াল
# সিইসিকে------সিইসি
# বাহুবলে------বাহুবল
# অসহায়ত্বের------অসহায়ত্ব
# নদীশাসনের------নদীশাসন
# প্রণেতারাও------প্রণেতা
# নৃবিজ্ঞানের------নৃবিজ্ঞান
# নবদ্বীপেই------নবদ্বীপ
# পীরগঞ্জের------পীরগঞ্জ
# ফরম্যাটেই------ফরম্যাট
# দলগুলোই------দল
# ফরম্যাটেও------ফরম্যাট
# পুত্রবধূর------পুত্রবধূর
# মুখচ্ছবির------মুখচ্ছবির
# দুঃসংবাদটা------দুঃসংবাদ
# দুঃসংবাদটি------দুঃসংবাদ
# দলগুলোও------দল
# ফরম্যাটের------ফরম্যাট
# কাইয়ুমদের------কাইয়ুম
# ধর্মঘটকে------ধর্মঘটক
# নবদ্বীপের------নবদ্বীপ
# দলগুলোর------দল
# অধ্যাদেশকে------অধ্যাদেশ
# আন্দোলনকে------আন্দোলন
# ঝুলটা------ঝুল
# পাঠকক্ষে------পাঠকক্ষ
# মুজিবও------মুজিব
# বেনাগলিওর------বেনাগলিও
# আইএসপিদের------আইএসপি
# পরিহারের------পরিহার
# দলগুলির------দল
# দূতেরা------দূতেরা
# মির্জার------মির্জা
# মুজিবে------মুজিব
# ফরমানগুলোর------ফরমান
# কৈরালাকে------কৈরালা
# প্লটও------প্লট
# প্লটে------প্লটে
# অযোগ্যদের------অযোগ্য
# ফর্মুলাটি------ফর্মুলা
# মোড়লের------মোড়ল
# বনশ্রীর------বনশ্রী
# অধ্যাদেশটা------অধ্যাদেশ
# অধ্যাদেশটি------অধ্যাদেশ
# প্লটই------প্লট
# স্বার্থবাদীদের------স্বার্থবাদী
# আরামবাগে------আরামবাগ
# মিথ্যাটি------মিথ্যা
# চিম্বুকের------চিম্বুক
# লোনাপানিতে------লোনাপানি
# দাবিতে------দাবি
# বৌদ্ধবিহারেও------বৌদ্ধবিহার
# ফ্র্যাঞ্চাইজের------ফ্র্যাঞ্চাইজ
# সমাধানটা------সমাধান
# সমাধানটি------সমাধান
# রেপ্রিজেন্টেশনের------রেপ্রিজেন্টিটন
# বৌদ্ধবিহারের------বৌদ্ধবিহার
# ফ্রিকোয়েন্সিতেই------ফ্রিকোয়েন্সি
# আফসানের------আফসান
# ফয়েজের------ফয়েজ
# সেলুনে------সেলুন
# তাজিকিস্তানকে------তাজিকিস্তান
# গাইনের------গাইন
# রেলিংয়ের------রেলিং
# হাটহাজারীতে------হাটহাজারী
# জজদেরও------জজদ
# জীবনধারায়------জীবনধা
# মোকাদ্দাসে------মোকাদ্দাস
# নিশ্চিন্তপুরে------নিশ্চিন্তপুর
# জনগোষ্ঠীরই------জনগোষ্ঠী
# প্রকল্পগুলো------প্রকল্প
# গণধর্ষণের------গণধর্ষণ
# পণ্ডিতদের------পণ্ডিত
# কারজাইকে------কারজাই
# স্বৈরশাসকের------স্বৈরশাসক
# ইডিমাকে------ইডিমা
# নিম্নগতির------নিম্নগতি
# সাফিয়ার------সাফিয়া
# ফ্র্যাঞ্চাইজির------ফ্র্যাঞ্চাইজি
# টমিকের------টমিক
# শিপইয়ার্ডে------শিপইয়ার্ড
# নারীশিক্ষায়------নারীশিক্ষা
# জীবনধারার------জীবনধারা
# চক্রেরই------চক্র
# সানিয়াকে------সানিয়া
# ফ্র্যাঞ্চাইজিও------ফ্র্যাঞ্চাইজি
# নারীশিক্ষার------নারীশিক্ষা
# বরাতে------বরাতে
# দাঙ্গাবাজারে------দাঙ্গাবাজার
# প্রোর------প্রোর
# দাবিরও------দাবি
# নিয়োগপ্রক্রিয়ায়------নিয়োগপ্রক্রিয়া
# আফসানার------আফসানা
# প্রোই------প্রো
# ভাটাগুলো------ভাটা
# হারবারটি------হারবার
# কৃষিজমিকে------কৃষিজমি
# লিপগ্লসের------লিপগ্লস
# বিভাগটিকে------বিভাগ
# আয়শাকে------আয়শা
# নিয়োগপ্রক্রিয়ার------নিয়োগপ্রক্রিয়া
# বিজয়ীকে------বিজয়ী
# থ্রোতে------থ্রোতে
# মোহনগঞ্জে------মোহনগঞ্জ
# আখুঞ্জীকে------আখুঞ্জী
# মোড়লকে------মোড়ল
# বাকপ্রতিবন্ধীর------বাকপ্রতিবন্ধী
# আহসানের------আহসান
# বিজ্ঞপ্তিটি------বিজ্ঞপ্তি
# গবেষণাকাজে------গবেষণাকাজ
# দাবিকে------দাবি
# কৌটাগুলো------কৌটা
# বরাকে------বরা
# বাংলাদেশটাকে------বাংলাদেশ
# মীরজাফরকে------মীরজাফর
# বর্ণবাদকে------বর্ণবাদ
# বিজয়ীরা------বিজয়ী
# পাইয়ে------পাইয়ে
# মনোগ্রামে------মনোগ্রাম
# জাদুঘরেরই------জাদুঘর
# নামগুলোর------নাম
# ডিএফআইয়ের------ডিএফআই
# ঝুরির------ঝুরি
# বিয়েতেও------বিয়ে
# ওগুলোকে------ওগুলো
# গণরুমে------গণরুম
# থামতেও------থামতে
# থামতেই------থামতেই
# এয়ারলাইনসের------এয়ারলাইনস
# সমাধানকে------সমাধান
# হারামের------হারাম
# ড্রাগের------ড্রাগ
# টিকিটগুলো------টিকিট
# ট্রানজিটও------ট্রানজিট
# প্রক্রিয়াজাতকরণে------প্রক্রিয়াজাত
# নাদালকে------নাদাল
# বিজ্ঞপ্তিকে------বিজ্ঞপ্তি
# সাতচল্লিশে------সাতচল্লিশ
# আকিজের------আকিজ
# ট্রানজিটে------ট্রানজিট
# মেডিসিনের------মেডিসিন
# বিভাগটিতে------বিভাগ
# দাবিটি------দাবি
# ফিফায়------ফিফা
# উইন্ডোর------উইন্ডো
# টনসিলের------টনসিল
# ইভটিজিংয়ের------ইভটিজিং
# গেরিলারাও------গেরিলা
# ওলস্ট্যানক্র্যাফটের------ওলস্ট্যান্র্যস
# উপমন্ত্রীদের------উপমন্ত্রী
# উত্তরাধিকারীর------উত্তরাধিকারী
# পাঠকক্ষকে------পাঠকক্ষক
# উপহারদাতাদের------উপহারদাতা
# দারুইনে------দারুইন
# গবেষণাপত্রটি------গবেষণাপত্র
# হিনার------হিনা
# প্রক্রিয়াকেও------প্রক্রিয়া
# ব্যক্তিশ্রেণীর------ব্যক্তিশ্রেণী
# কিকের------কিক
# গ্যাসকূপের------গ্যাসকূপ
# তাজিকিস্তানের------তাজিকিস্তান
# পয়সায়ও------পয়সা
# শাহবাজের------শাহবাজ
# শারজায়ই------শারজা
# সুবর্ণার------সুবর্ণা
# সরালেও------সরাল
# ঝুলের------ঝুল
# অন্যকেও------অন্যক
# কুরিয়ারগুলোও------কুরিয়ার
# অধিবেশনটি------অধিবেশন
# অধিবেশনটা------অধিবেশন
# পিরিস্ত্রোইকাকে------পিরিস্ত্রোইকা
# রিপোর্টাররা------রিপোর্টার
# ওভারটাই------ওভার
# শরীরচর্চার------শরীরচর্চা
# ওলাঁদকেই------ওলাঁদ
# কবিরুলকে------কবিরুল
# ডিগারের------ডিগার
# দর্শানোর------দর্শানো
# গবেষণাপত্রকে------গবেষণাপত্র
# স্ক্যানারের------স্ক্যানার
# জয়ললিতার------জয়ললিতা
# স্পাইডারম্যানদের------স্পাইডারম্যান
# রাজখোয়ার------রাজখোয়া
# ওভারটার------ওভার
# কেনাবেচায়------কেনাবেচা
# পাঞ্জাবিরা------পাঞ্জাবি
# আবুবকরের------আবুবকর
# ভ্যালেরিকে------ভ্যালেরি
# অভিযোগকারিণীর------অভিযোগকারিণী
# ওভারটির------ওভার
# বার্গক্যাম্পদের------বার্গক্যাম্প
# রিকসের------রিকস
# কিকেই------কিকে
# ট্রান্সফারের------ট্রান্সফার
# মরিচকে------মরিচ
# ট্রটেরও------ট্রট
# আড়িয়লে------আড়িয়ল
# টরির------টরি
# মহিলাদের------মহিলাদ
# বাসিরকে------বাসির
# ভূগোলের------ভূগোল
# শিখনপ্রতিবন্ধীদের------শিখনপ্রতিবন্ধী
# মুরব্বিদেরও------মুরব্বিদ
# নেপিডোর------নেপিডো
# কবজায়------কব
# অপরাধীও------অপরাধী
# আয়েশাই------আয়েশাই
# কালাতে------কালা
# অপরাধীর------অপরাধী
# তুলনাই------তুলনা
# নোবেলজয়ীর------নোবেলজয়ী
# আয়েশার------আয়েশা
# অধিবেশনকে------অধিবেশন
# রহস্যই------রহস্য
# রহস্যও------রহস্য
# গবেষণাকর্মে------গবেষণাকর্ম
# খাওনের------খাওন
# অপরাধীই------অপরাধী
# তুলনাও------তুলনা
# নানকশাহীতে------নানকশাহী
# কারাতের------কারাত
# তুলনার------তুলনা
# কেনাবেচার------কেনাবেচার
# তুলনায়------তুলনা
# কারাতেই------কারাতে
# বৌদ্ধদের------বৌদ্ধ
# মোটরযানের------মোটরযান
# ইশান্তকে------ইশান্ত
# যুক্তরাষ্ট্রেরও------যুক্তরাষ্ট্র
# প্রাচ্যনাটের------প্রাচ্যনাট
# নাজিয়াকে------নাজিয়া
# যুক্তরাষ্ট্রেরই------যুক্তরাষ্ট্র
# পাঞ্জাবিতে------পাঞ্জাবি
# হীরকের------হীরক
# শরীরচর্চায়------শরীরচর্চা
# অ্যালেক্সের------অ্যালেক্স
# সাভারে------সাভার
# কটেজগুলো------কটেজ
# একেকটির------একেক
# মঙ্গলের------মঙ্গল
# মৌয়ালেরা------মৌয়াল
# সামিয়ার------সামিয়া
# শিষ্টাচারের------শিষ্টাচার
# বঙ্গভবনকে------বঙ্গভবন
# পটুয়াখালীতে------পটুয়াখালী
# বিউফোর্ডকে------বিউফোর্ড
# সাইটে------সাইট
# ক্রয়ে------ক্রয়ে
# প্রভাষকদের------প্রভাষক
# মঙ্গলেও------মঙ্গল
# গম্ভীরকেও------গম্ভীর
# বিপণিকেন্দ্রেও------বিপণিকেন্দ্র
# গরিবরা------গরিব
# ইউসেফের------ইউসেফ
# বিপণিকেন্দ্রের------বিপণিকেন্দ্র
# ডিভাইসও------ডিভাইস
# পাওয়ারলুমের------পাওয়ারলুম
# হারিরিকে------হারিরি
# পতনটি------পতন
# পতনটা------পতন
# পিত্তের------পিত্ত
# আকাশের------আকাশ
# নাদালও------নাদাল
# ডিমোকের------ডিমোক
# নাদালই------নাদাল
# সাইজে------সাইজ
# হ্যাটট্রিকের------হ্যাটট্রিক
# সোহাগীর------সোহাগী
# যুগোশ্লাভিয়ার------যুগোশ্লাভিয়া
# অধিবেশনেও------অধিবেশন
# থামলেই------থামলে
# সাইটও------সাইট
# সাইটই------সাইট
# আকাশেই------আকাশ
# অধিবেশনেই------অধিবেশন
# কথিকায়------কথিকা
# তোদের------তোদের
# দীর্ঘদিনের------দীর্ঘদিন
# মাত্রাগুলোর------মাত্রা
# সকলেরই------সকল
# এনভিডিয়ার------এনভিডিয়া
# ক্রিকেটপ্রেমীরা------ক্রিকেটপ্রেমী
# কাচবালুতে------কাচবালু
# জাহাজভাঙায়------জাহাজভাঙা
# অনুগতদের------অনুগত
# অধিবেশনের------অধিবেশন
# সকলেরে------সকলে
# দার্শনিকদের------দার্শনিক
# স্টারউডকে------স্টারউড
# তথ্যাদির------তথ্যাদি
# শহীদকে------শহীদ
# জাহাজভাঙার------জাহাজভাঙা
# অচিরেই------অচি
# তথ্যাদিও------তথ্যাদি
# শস্যগুলোর------শস্য
# সাকলায়েনের------সাকলায়েন
# ক্রোর------ক্রো
# গোডাউনে------গোডাউন
# পয়সাকে------পয়সা
# মুহিউদ্দিনের------মুহিউদ্দিন
# হারানোর------হারানো
# সিসকোকে------সিসকো
# ক্রোও------ক্রো
# অভিযোগকেন্দ্রে------অভিযোগকেন্দ্র
# ফিনের------ফিন
# নাসিরকে------নাসির
# অপ্রকাশ্যে------অপ্রকাশ্য
# গরিবের------গরিব
# সংসারের------সংসার
# যুবরাজেরই------যুবরাজ
# মানবতায়------মানবতা
# নিকটবর্তীও------নিকটবর্তী
# দমননীতিতে------দমননীতি
# মানবতার------মানবতা
# সংসারেও------সংসা
# সংসারেই------সংসার
# সমস্যাটাকে------সমস্যাটাক
# দলগতভাবেই------দলগতভাবে
# খনিশ্রমিকদের------খনিশ্রমিক
# সেকেন্ডের------সেকেন্ড
# মিস্ত্রীকে------মিস্ত্রী
# পশুপাখির------পশুপাখি
# রিপাকে------রিপাক
# সংসারকেই------সংসার
# নরিয়েগার------নরিয়েগা
# কাবাগৃহের------কাবাগৃহ
# কাফ্ফারার------কাফ্ফারা
# রিটেই------রিট
# পশুপাখিও------পশুপাখি
# সেকেন্ডেই------সেকেন্ড
# রিটের------রিট
# ক্যাটাগরিগুলোয়------ক্যাটাগরি
# তোতলার------তোতলা
# কমিটিও------কমিটি
# নৌঘাটের------নৌঘাট
# রিডকে------রিড
# সেলিনার------সেলিনা
# কমিটিই------কমিটি
# ধর্মান্ধদের------ধর্মান্ধ
# বৈসাবির------বৈসাবি
# রিপোর্টারের------রিপোর্টার
# ডিভাইসে------ডিভাইস
# ভাইবোনদের------ভাইবোন
# লরাঁও------লরাঁও
# মিস্ত্রিরা------মিস্ত্রি
# মান্নাও------মান্না
# খাঁড়ার------খাঁড়া
# কৃষ্ণগহ্বরের------কৃষ্ণগহ্বর
# মণিমালার------মণিমালা
# যুদ্ধটাই------যুদ্ধ
# তামাকচাষিরা------তামাকচাষি
# মান্নার------মান্না
# কোনোটাতে------কোনোটা
# কমিটির------কমিটি
# জালিয়াতচক্রের------জালিয়াতক্য
# পরিপ্রেক্ষিতের------পরিপ্রেক্ষি
# বায়রাও------বায়রা
# মানবতাই------মানবতা
# বায়রার------বায়রা
# অনুমতিপত্রের------অনুমতিপত্র
# আকাশরে------আকাশ
# বুলাওয়ের------বুলাওয়ে
# লরাঁর------লরাঁ
# ফোয়ারার------ফোয়ারা
# শাড়িটির------শাড়ি
# পরিপ্রেক্ষিতেই------পরিপ্রেক্ষি
# পরিপ্রেক্ষিতেও------পরিপ্রেক্ষি
# শাড়িটিও------শাড়ি
# শাড়িটার------শাড়ি
# স্বার্থসংশ্লিষ্টদের------স্বার্থসংশ্ল্ষ
# বেড়িবাঁধগুলোও------বেড়িবাঁধ
# সোহাগকে------সোহাগ
# নাসিরের------নাসির
# উভয়ই------উভয়
# কলামটিতে------কলাম
# এফইজেবির------এফইজেবি
# সাটারিংয়ের------সাটারিং
# গরিবকে------গরিব
# গরুগুলোকে------গরু
# পথিকৃত্ও------পথিকৃত্
# উমার------উমার
# সাকলায়েনকে------সাকলায়েন
# বেড়িবাঁধগুলোর------বেড়িবাঁধ
# পাঠ্যক্রমের------পাঠ্যক্রমের
# মাংসে------মাংস
# সংস্কারপন্থীরা------সংস্কারপন্থী
# ইশান্তের------ইশান্ত
# ক্রুর------ক্রু
# অভ্যুত্থানের------অভ্যুত্থান
# ফিনকে------ফিন
# নভোযানটির------নভোযান
# যুদ্ধবিমানগুলোয়------যুদ্ধবিমান
# রিকশাশ্রমিকের------রিকশাশ্রমিক
# সিসিতে------সিসি
# মাংসও------মাংস
# আল্টিমেটামের------আল্টিমেটাম
# ক্ষতের------ক্ষত
# সরওয়ার্দীর------সরওয়ার্দী
# সিএমসির------সিএমসি
# নীলফামারীর------নীলফামারী
# বচ্চনই------বচ্চন
# পরিবেশকে------পরিবেশ
# ইকরামকে------ইকরাম
# পরিবেশকও------পরিবেশক
# উইকেটগুলো------উইকেট
# শ্রোতারা------শ্রোতা
# কাজিমের------কাজিম
# মুড়ালিগুলো------মুড়ালি
# নাতাশাকে------নাতাশা
# নানুমণির------নানুমণি
# অ্যালার্মের------অ্যালার্ম
# সিটুইয়ের------সিটুই
# ডায়াবেটিসকে------ডায়াবেটিস
# নাজিমউদ্দিনও------নাজিমউদ্দিন
# বিয়ারজোতের------বিয়ারজো
# গ্রুপগুলোই------গ্রুপ
# রণবীরের------রণবীর
# ক্ষতিও------ক্ষতি
# গ্রেপ্তারই------গ্রেপ্তা
# ভূঁইয়াকেও------ভূঁইয়া
# পরিপ্রেক্ষিতকে------পরিপ্রেক্ষিক
# ক্ষতিই------ক্ষতি
# টিন্ডালের------টিন্ডাল
# উপাচার্যকে------উপাচার্য
# গ্রেপ্তারও------গ্রেপ্তা
# ক্ষতির------ক্ষতি
# গ্রুপগুলোর------গ্রুপ
# ফেরিঘাটে------ফেরিঘাট
# লরাকে------লরা
# ভিডিওবার্তাটি------ভিডিওবার্তা
# অর্থবছরেরও------অর্থবছর
# বর্ষণের------বর্ষণ
# ছেলেমেয়েদের------ছেলেমেয়ে
# উমরও------উমর
# স্টারের------স্টার
# গ্রেপ্তারে------গ্রেপ্তার
# হেমায়েতকে------হেমায়েত
# বেতবুনিয়ার------বেতবুনিয়া
# চাওলার------চাওলা
# কোনোটিরই------কোনোটি
# গণগ্রেপ্তারে------গণগ্রেপ্তা
# ওয়ার্কওভারের------ওয়ার্কওভার
# পতনকে------পতন
# শালমের------শালম
# ভাইদেরও------ভাইদ
# কেমোথেরাপিতে------কেমোথেরাপি
# পূজামন্দিরে------পূজামন্দি
# হ্যাটট্রিকেই------হ্যাটট্রিক
# সাউদির------সাউদি
# কাজিমরা------কাজিম
# রডিনকে------রডিন
# নির্গমনের------নির্গমন
# মিস্ত্রিকে------মিস্ত্রিক
# মহিলাতেও------মহিলাত
# প্যাটারসনের------প্যাটারসন
# ডেটাসফটের------ডেটাসফট
# দণ্ডবিধিতে------দণ্ডবিধি
# সুপারিগাছে------সুপারিগাছ
# ঝরনাকে------ঝরনা
# শাখাপ্রধানের------শাখাপ্রধান
# মধ্যস্থতাকারীর------মধ্যস্থতাকারী
# কর্মকর্তাদেরই------কর্মকর্তা
# কর্মকর্তাদেরও------কর্মকর্তা
# অসুবিধার------অসুবিধা
# পতাকায়------পতাকা
# এইচপিসির------এইচপিসি
# পতাকার------পতাকা
# প্রার্থনালয়ে------প্রার্থনালয়
# তাদেরও------তাদের
# সেলাইও------সেলাই
# স্টপেজও------স্টপেজ
# ইসরাইলের------ইসরাইল
# তাদেরই------তাদের
# কাঁঠালটা------কাঁঠাল
# কাশির------কাশি
# পতাকাও------পতাকা
# এতটাই------এত
# অসুবিধায়------অসুবিধা
# কোনোটিতে------কোনোটি
# ক্যুর------ক্যু
# পতাকাই------পতাকা
# স্টপেজে------স্টপেজ
# রিকশায়------রিকশা
# তিহারিটা------তিহারি
# রিবেরির------রিবেরি
# ক্যামব্রিজশায়ারের------ক্যামব্রিজশায়ার
# রিকশার------রিকশা
# চাঙাভাবের------চাঙাভাব
# সাইফই------সাইফ
# রিবেরিই------রিবেরি
# একেকটার------একেক
# রিকশাও------রিকশা
# পরিবেশটা------পরিবেশ
# পরিবেশটি------পরিবেশ
# অসুবিধাও------অসুবিধা
# লাশটিও------লাশ
# রেলগাড়িতে------রেলগাড়ি
# ইনজামামের------ইনজামাম
# মহেশখালীর------মহেশখালী
# লাশটাও------লাশ
# জামানও------জামান
# শিশুপুত্রকে------শিশুপুত্র
# তাহাদিগকেই------তাহাদিগ
# অসমিয়ারা------অসমিয়া
# লাশটাই------লাশ
# লিগটাই------লিগ
# ক্লিনিকটির------ক্লিনিক
# হেল্পলাইনের------হেল্পলাইন
# সরকারটি------সরকার
# সুশাসনে------সুশাসন
# আকিকার------আকিকা
# জামাতে------জামা
# শাহেনার------শাহেনা
# লিখিতও------লিখিত
# আপিলেরও------আপিল
# স্টাফকে------স্টাফ
# নদীবন্দরই------নদীবন্দর
# বনবিভাগের------বনবিভাগ
# উদ্ধারকর্তার------উদ্ধারকর্তা
# গোলাপজামের------গোলাপজাম
# সিআরবিএলপির------সিআরবিএচ
# লাশটির------লাশ
# হোনড্রোসের------হোনড্রোস
# গ্রন্থমেলাকে------গ্রন্থমেলা
# রক্ষণভাগকেও------রক্ষণভাগ
# জামাটি------জামা
# কয়েসও------কয়েস
# জামাটা------জামা
# ট্যাক্সিতে------ট্যাক্সি
# ভিনসেতির------ভিনসেতি
# যুদ্ধাপরাধদের------যুদ্ধাপরাধ
# মেদিনীপুরের------মেদিনীপুর
# ছোটবেলায়------ছোটবেলা
# ফটফটিয়ার------ফটফটি
# রামনগরের------রামনগর
# টবেও------টবে
# টবেই------টবে
# টবের------টব
# ছোটবেলার------ছোটবেলা
# দাইমারিকে------দাইমারি
# জগৎশেঠদের------জগৎশেঠ
# পেয়াদারও------পেয়াদার
# নেটবুকগুলো------নেটবুক
# টেপরেকর্ডারটি------টেপরেকর্ডার
# তায়েবাকে------তায়েবা
# পাঠ্যক্রমটি------পাঠ্যক্রম
# পাঠ্যক্রমটা------পাঠ্যক্রম
# সংসারকে------সংসার
# অষ্টমীর------অষ্টমী
# ফিডের------ফিড
# কাঁচামরিচের------কাঁচামরিচ
# সিসেকে------সিসে
# অলিভারের------অলিভার
# ঘোষণারও------ঘোষণা
# সমঝোতাকারীরা------সমঝোতাকারী
# লাঞ্ছনাকারীদের------লাঞ্ছনাকারী
# রণবীরকে------রণবীর
# নাসিমকে------নাসিম
# নঈমের------নঈম
# জুমেরার------জুমেরা
# মূর্খেরই------মূর্খ
# লিখিবে------লিখিব
# খুনটি------খুন
# খুনটা------খুন
# অটোরিকশাটিকে------অটোরিকশা
# আলভেরোর------আলভেরো
# আবেদনগুলোর------আবেদন
# নিজামবাগের------নিজামবাগ
# বিমানবন্দরটির------বিমানবন্দর
# সংগঠনেরও------সংগঠন
# বিড়ালটা------বিড়াল
# বিড়ালটি------বিড়াল
# ঘুমিয়েই------ঘুমিয়ে
# মিজোরামে------মিজোরাম
# পর্বতচূড়ায়------পর্বতভূড়া
# সংগঠনেরই------সংগঠন
# রাষ্ট্রপক্ষের------রাষ্ট্রপক্ষ
# ডায়াবেটিসের------ডায়াবেটিস
# লোকালয়ের------লোকালয়
# পরিবেশককে------পরিবেশক
# মেয়েশিশুরা------মেয়েশিশু
# প্যাটারসনকে------প্যাটারসন
# ছিটকিনিটার------ছিটকিনি
# চ্যাটে------চ্যাট
# সিআরবিসির------সিআরবিসি
# ওয়াটারকে------ওয়া
# পটুয়াখালীর------পটুয়াখালী
# জামারও------জামা
# সরকারকে------সরকার
# রক্ষণশীলতারই------রক্ষণশীলতা
# পারেরহাটের------পারেরহাট
# বাকিয়েভেরও------বাকিয়েভ
# টমকে------টমক
# ন্যাপেরও------ন্যাপ
# বিএসএফেরই------বিএসএফ
# ভোলার------ভোলা
# পারলারটির------পারলার
# প্রাকদরপত্রে------প্রাকদরপত্র
# চিন্তাকাঠামোর------চিন্তাকাঠামো
# জামালে------জামাল
# নুসরাতের------নুসরাত
# ডিরেক্টরিতে------ডিরেক্টরি
# ভোলায়------ভোলা
# ঘোষণাটি------ঘোষণা
# ঘোষণাটা------ঘোষণা
# জামালও------জামাল
# চ্যানই------চ্যান
# হাতিরপুলে------হাতিরপুল
# পাটবীজের------পাটবীজ
# ইমেজিংয়ের------ইমেজিং
# আকাশটা------আকাশ
# নাসিমের------নাসিম
# খণ্ডনও------খণ্ডন
# লেখাপড়ায়------লেখাপড়া
# ওয়েস্টকে------ওয়েস্ট
# দাসশ্রমের------দাসশ্রম
# পুলিয়ামারীর------পুলিয়ামারী
# বাঁহাতির------বাঁহাতি
# জামিনও------জামিন
# বিদাকে------বিদা
# বাল্বই------বাল্ব
# লেখাপড়াও------লেখাপড়া
# তেলাওয়াতের------তেলাওয়াত
# শ্রীলঙ্কানদের------শ্রীলঙ্কান
# মেলাটির------মেলা
# বাল্বও------বাল্ব
# নঈমকে------নঈম
# লেখাপড়ার------লেখাপড়া
# পশুমেলায়------পশুমেলা
# আকলিমাও------আকলিমা
# জামিনে------জামিন
# রিটটি------রিট
# মেলাটার------মেলা
# খুলশীতে------খুলশী
# সরকারেও------সরকার
# সরকারেই------সরকার
# কালিমুল্লাহর------কালিমুল্লাহ
# অনলাইনে------অনলাইন
# দিবসকেও------দিবস
# এসআইপিপিরই------এসআইপিপি
# মাউলে------মাউলে
# ফুসফুসও------ফুসফুস
# সহসভাপতিকে------সহসভাপতি
# কামিলের------কামিল
# ভিজিটরের------ভিজিটর
# পলিশগুলো------পলিশ
# জনপ্রতিনিধিরা------জনপ্রতিনিধি
# বিডিনিউজের------বিডিনিউজ
# নাসিমার------নাসিমা
# টোয়েনের------টোয়েন
# ফ্যারাডের------ফ্যারাড
# লুৎফার------লুৎসা
# স্টাফরা------স্টাফরা
# সম্পর্ককেও------সম্পর্ক
# কারের------কার
# ধর্মান্ধতার------ধর্মান্ধতা
# খুনকে------খুন
# রিটকে------রিট
# সুমরোর------সুমরো
# খণ্ডটি------খণ্ড
# মিলিব্যান্ডের------মিলিব্যান্ড
# সরকারের------সরকার
# ফুসফুসে------ফুসফুস
# লেখকটি------লেখক
# বাইসাইকেলে------বাইসাইকেল
# আকলিমার------আকলিমা
# যোগসাজশে------যোগসাজশ
# ঋণগ্রহীতারা------ঋণগ্রহীতা
# কামিলাই------কামিলা
# অফিসগুলোর------অফিস
# অতীতকেও------অতীত
# ইটলসের------ইটলস
# স্থিতির------স্থিতি
# কামিলার------কামিলা
# জন্ডিসে------জন্ডিস
# এলেক্সির------এলেক্সি
# ঈশ্বরদীতেও------ঈশ্বরদী
# জনপ্রিয়তারই------জনপ্রিয়তা
# শাহেদের------শাহেদ
# বোমারুর------বোমারু
# কয়েদিরাও------কয়েদি
# ইন্টারফেসটির------ইন্টারফেস
# হোনড্রোসকে------হোনড্রোস
# কোলম্যানকে------কোলম্যান
# আকুলতার------আকুলতা
# দুলাভাইয়ের------দুলাভাই
# তোপধ্বনির------তোপধ্বনি
# হারাগাছেরই------হারাগাছ
# বহুমুখীকরণের------বহুমুখীকরণ
# কেমব্রিজের------কেমব্রিজ
# কোটবাড়িতে------কোটবাড়ি
# বিরোধগুলো------বিরোধ
# জয়ন্তীকে------জয়ন্তী
# কেমব্রিজেই------কেমব্রিজ
# ল্যান্ডিংয়ের------ল্যান্ডিং
# সিদ্দিকিকে------সিদ্দিকি
# মহামন্দাকে------মহামন্দা
# আয়করবিবরণীতে------আয়করবিবরণী
# লেখককে------লেখক
# আদভানিকে------আদভানি
# সম্মোধনের------সম্মোধন
# অগ্রসরের------অগ্রসর
# সংসারটা------সংসার
# সংসারটি------সংসার
# নভোথিয়েটারে------নভোথিয়েটার
# আকাশকে------আকাশ
# জনপ্রতিনিধিকে------জনপ্রতিনিধি
# ছোটার------ছোটা
# গোষ্ঠীটিকে------গোষ্ঠী
# জামিলও------জামিল
# ক্যাফেটেরিয়ার------ক্যাফেটেরি
# জীবনসংগ্রামে------জীবনসংগ্রাম
# আইএইএর------আইএইএ
# খানাকে------খানা
# ম্যাথুজকে------ম্যাথুজ
# আকিকের------আকিক
# শাহবাগের------শাহবাগ
# গ্রসকে------গ্রস
# সোহাগের------সোহাগ
# জলদস্যুদেরও------জলদস্যুদ
# শিবপুরের------শিবপুর
# স্যালনের------স্যালন
# প্রাণভিক্ষার------প্রাণভিক্ষা
# বিড়ালের------বিড়াল
# প্রতিরক্ষার------প্রতিরক্ষা
# প্রতিরক্ষায়------প্রতিরক্ষা
# মাউসে------মাউস
# মহাব্যবস্থাপকের------মহাব্যবস্থাপক
# সার্দাইকোভের------সার্দাইকোভ
# ধারাসমূহের------ধারাসমূহ
# কূপগুলোতে------কূপ
# ভিটেবাড়িটির------ভিটেবাড়ি
# ট্রেনেরই------ট্রেন
# খুদার------খুদার
# জামীকে------জামী
# ছোটেও------ছোট
# দৃশ্যকল্পের------দৃশ্যকল্প
# ট্রেনেরও------ট্রেন
# ম্যাসনের------ম্যাসন
# রাজদর্শনের------রাজদর্শন
# বকেয়ার------বকেয়া
# ডুমিনিকে------ডুমিনি
# তথ্যচিত্রটির------তথ্যচিত্র
# লেখকের------লেখক
# ঘটনাটাই------ঘটনা
# রাষ্ট্রপক্ষকে------রাষ্ট্রপক্ষ
# তোতাপাখিটা------তোতাপাখি
# তোতাপাখিটি------তোতাপাখি
# ডিজাইনিংয়ে------ডিজাইনিং
# ইনস্টিটিউটগুলো------ইনস্টিটিউট
# দৃশ্যকল্পটি------দৃশ্যকল্প
# ভাঙাড়িরা------ভাঙাড়ি
# ওয়াটারের------ওয়া
# রেজুলেশনের------রেজুলেশন
# টমের------টম
# ব্যবস্থাগুলো------ব্যবস্থা
# ইতিকাফকারীর------ইতিকাফকারী
# ডিপোগুলো------ডিপোগুলো
# লিডটাকেই------লিড
# খটখটিয়ার------খটখটিয়া
# চেনিকে------চেনি
# জুজুবুড়ির------জুজুবুড়ি
# স্মৃতিসৌধে------স্মৃতিসৌধ
# তুলতেই------তুলতে
# আসাদুলের------আসাদুল
# কালিকে------কালি
# খণ্ডের------খণ্ড
# এফইউপিতে------এফইউপি
# রেসিপির------রেসিপি
# প্রতিক্রিয়াও------প্রতিক্রিয়া
# সম্ভাষণের------সম্ভাষণ
# কাউন্টারগুলোর------কাউন্টার
# মরিচের------মরিচ
# তাম্রলিপির------তাম্রলিপি
# নুসরাতকে------নুসরাত
# ইয়ার্ডে------ইয়ার্ড
# কালিতে------কালি
# প্রতিক্রিয়াই------প্রতিক্রিয়া
# হাক্কানির------হাক্কানি
# ব্যবসায়ীরাই------ব্যবসায়ী
# তাজিকরা------তাজিক
# ইলিয়েভস্কির------ইলিয়েভস্কি
# অধর্মই------অধর্ম
# ব্যবসায়ীরাও------ব্যবসায়ী
# শ্বাসনালির------শ্বাসনালি
# ঋণগ্রহীতাকে------ঋণগ্রহীতা
# ফিতরে------ফিতর
# ইডিয়টও------ইডিয়ট
# আমদানিপণ্যের------আমদানিপণ্য
# ছোটরা------ছোট
# বুলেটে------বুলেট
# প্রতিক্রিয়ায়------প্রতিক্রিয়া
# প্রতিক্রিয়ার------প্রতিক্রিয়া
# টংদোকানের------টংদোকান
# উদ্যোগকে------উদ্যোগ
# মুদ্রাকরের------মুদ্রাকর
# স্টাফের------স্টাফ
# কফিনে------কফিন
# রাষ্ট্রনেতার------রাষ্ট্রনেতা
# ডুয়ার্সে------ডুয়ার্স
# স্টাফেও------স্টাফ
# ডুমিনিরও------ডুমিনি
# বর্জ্যও------বর্জ্য
# বলটনের------বলটন
# অ্যারিসকে------অ্যারিস
# সমঝোতাগুলোর------সমঝোতা
# রচনাটিতে------রচনা
# পারতেই------পারতে
# গৃহস্থালীর------গৃহস্থালী
# ...
# বাঞ্ছারামপুরের------বাঞ্ছারামপুর
# ছাপরাঘরের------ছাপরাঘর
# মারামারিকে------মারামারি
# অমৃতের------অমৃত
# স্টাডিতে------স্টাডি
# পঞ্চমের------পঞ্চম
# পাওয়ারটেকের------পাওয়ারটেক
# ওয়াকারকে------ওয়াকার
# তিব্বতকে------তিব্বত
# আইসবার্গকে------আইসবার্গ
# এককগুলো------একক
# সিওওর------সিওও
# পাউন্ডে------পাউন্ড
# তাণ্ডবের------তাণ্ডব
# ডিরেক্টরিগুলো------ডিরেক্টরি
# কামরুলের------কামরুল
# পাউন্ডও------পাউন্ড
# ধান্ধায়------ধান্ধা
# কাটটি------কাট
# ফেরিগুলোকে------ফেরি
# রশির------রশি
# উত্তরদাতারা------উত্তরদাতা
# প্রবেশদ্বারে------প্রবেশদ্বার
# নিয়োগদানের------নিয়োগদান
# মৌচাকে------মৌচা
# মডারেটে------মডারেট
# ভাস্করকে------ভাস্কর
# কাটছে------কাটছে
# সকেটের------সকেট
# পন্টুনেরও------পন্টুন
# দলিলের------দলিল
# মৌসুমগুলো------মৌসুম
# প্রতিরক্ষাব্যবস্থাকে------প্রতিরক্ষাব্বস্থা
# এজিপিরা------এজিপি
# মাহামুদুলকে------মাহামুদুল
# কিবরিয়াও------কিবরিয়া
# রুবেনার------রুবেনা
# ভূমিকাটিও------ভূমিকা
# ইউনিভার্সের------ইউনিভার্স
# দরখাস্তের------দরখাস্ত
# প্রদেশগুলো------প্রদেশ
# মারামারিতে------মারামারি
# ভূমিকাটাই------ভূমিকা
# ন্যায়কে------ন্যায়
# সংস্করণটির------সংস্করণ
# কিবরিয়ার------কিবরিয়া
# যুক্তিকে------যুক্তি
# ঋষিদের------ঋষি
# আইএসএনের------আইএসএন
# মাস্টার্সেই------মাস্টার্স
# অনুষ্ঠানটিকে------অনুষ্ঠান
# সালকে------সাল
# লাশগুলোর------লাশ
# লিগগুলোর------লিগ
# দলিলটি------দলিল
# দলিলটা------দলিল
# লিগগুলোয়------লিগ
# উেসর------উেসর
# প্রাইউসের------প্রাইউস
# আইসবার্গের------আইসবার্গ
# টরেসকে------টরেস
# মাস্টার্সের------মাস্টার্স
# রোমাকে------রোমা
# সম্পাদনায়ও------সম্পাদনা
# হোটেলগুলোকে------হোটেল
# শৈবালের------শৈবাল
# স্বাস্থ্যমন্ত্রীকে------স্বাস্থ্যমন্ত্র্তী
# অর্থমন্ত্রণালয়ের------অর্থমন্ত্রণালয়
# নৌকাতেই------নৌকাত
# ওভারটি------ওভার
# ওয়েতাহার------ওয়েতাহা
# ওভারটা------ওভার
# রাঘনার------রাঘনা
# শাকিনির------শাকিনি
# রেশনসুবিধার------রেশনসুবিধা
# রাঘনায়------রাঘনা
# শাসনামলে------শাসনামল
# আমানতকে------আমানত
# বছিলায়------বছিলা
# বাক্যাংশে------বাক্যাংশ
# ফার্গুসনের------ফার্গুসন
# টিসিএলকে------টিসিএল
# পূর্ববাংলায়------পূর্ববাংলা
# হবিবরের------হবিবর
# খাদ্যে------খাদ্য
# বাঁশগুলো------বাঁশ
# মোটিফকে------মোটিফ
# পূর্ববাংলার------পূর্ববাংলা
# ফরজের------ফরজ
# আগন্তুকের------আগন্তুক
# ড্রিবলিংয়ের------ড্রিবলিং
# ট্রান্সপোর্টের------ট্রান্সপোর্ট
# কাছেই------কাছে
# প্রফিটের------প্রফিট
# কাছেও------কাছে
# স্মার্টের------স্মার্ট
# যন্ত্রকৌশলীরা------যন্ত্রকৌশলী
# কাছের------কাছের
# ডিসিসির------ডিসিসি
# জিএইচআরডির------জিএইচআরডির
# তোফাজ্জেলের------তোফাজ্জেল
# সচিবেরা------সচিবেরা
# ওয়াশোনাইটকে------ওয়াশোনাইট
# কার্তিককেও------কার্তিক
# থাকায়------থাকা
# নাইরোবিতে------নাইরোবি
# টগরকে------টগর
# স্থায়ীয়------স্থায়ীয়
# নাট্যজনের------নাট্যজন
# উপগ্রহের------উপগ্রহ
# কামরুলকে------কামরুল
# থাকার------থাকা
# সেচপ্রকল্পের------সেচপ্রকল্প
# থাকাও------থাকা
# মহিলাটাকে------মহিলাটা
# থাকাই------থাকা
# কাজলও------কাজল
# পেপসিরটায়------পেপসির
# ভারতিকে------ভারতি
# সামির------সামি
# ভূমিমাইনে------ভূমিমাইন
# প্রকৃতপক্ষেই------প্রকৃতপক্ষ
# বিইআরসিও------বিইআরসি
# অধিকাংশের------অধিকাংশ
# পুদুচেরিতে------পুদুচেরি
# বিইআরসির------বিইআরসি
# ভগবতীকে------ভগবতী
# এমদাদুলকে------এমদাদুল
# কূটনীতিকের------কূটনীতিক
# কাজলে------কাজলে
# যাযাবরের------যাযাবর
# র‌্যানের------র‌্যান
# থাকেই------থাকেই
# উত্তরপত্রেই------উত্তরপত্র
# এলাচির------এলাচি
# আরএসইউকে------আরএসইউ
# সদস্যরাষ্ট্রে------সদস্যরাষ্ট্র
# শমশেরনগরের------শমশেরন
# দাইমারির------দাইমারি
# রসুর------রসু
# ওঠাবসার------ওঠাবসা
# উত্তরপত্রের------উত্তরপত্র
# অঙ্কনের------অঙ্কন
# ভিক্টোরিয়ারই------ভিক্টোরিয়া
# মুসল্লির------মুসল্লি
# রসের------রস
# মাঠটি------মাঠ
# করপোরেশনগুলো------করপোরেশন
# মাঠটা------মাঠ
# মাটিও------মাটি
# হিমছড়িতে------হিমছড়ি
# মাটির------মাটি
# অক্ষরানন্দের------অক্ষরানন্দ
# রসেও------রস
# মাটিই------মাটি
# ম্যাসেজও------ম্যাসেজ
# এপিওবির------এপিওবি
# হাজারিকাকে------হাজারিকা
# ক্রিকেটটাকে------ক্রিকেট
# বিদ্যুত্সংকটের------বিদ্যুত্সংক
# আবিষ্কারকেরা------আবিষ্কারক
# সুবিধাভোগীরাই------সুবিধাভোগী
# এনইউএসের------এনইউএস
# সিঁড়িতে------সিঁড়ি
# বুনার্জির------বুনার্জি
# ন্যাড়ার------ন্যাড়া
# যোগবের------যোগব
# পিলাকের------পিলাক
# রসির------রসি
# ভূমিকম্পগুলোতে------ভূমিকম্প
# রসটা------রস
# রসটি------রস
# তারল্যসংকটের------তারল্যসংক
# কাজকে------কাজ
# এপোয়েলের------এপোয়েল
# রেলপথটি------রেলপথ
# আগন্তুককে------আগন্তুক
# পিনেরার------পিনেরা
# মিসরীয়টি------মিসরীয়
# জামিনদারের------জামিনদার
# বন্দরগুলো------বন্দর
# হত্যাগুলোর------হত্যা
# থাকবে------থাকবে
# রুবেলই------রুবেল
# রুবেলও------রুবেল
# সিঁড়িরও------সিঁড়ি
# পূর্বানুমতির------পূর্বানুমতি
# উপসচিবকে------উপসচিব
# শশীদলে------শশীদল
# মনোজকে------মনোজ
# যাত্রাবাড়ীর------যাত্রাবাড়ী
# কায়েতপাড়ায়------কায়েতপাড়া
# গদাধরডাঙ্গির------গদাধরডাঙ্গি
# কাজটা------কাজ
# কাজটি------কাজ
# থাকলই------থাকল
# নাট্যশালায়------নাট্যশালা
# রেলপথকে------রেলপথ
# একেনবেরির------একেনবেরি
# গণচিত্রে------গণচিত্র
# হারানোটাই------হারানো
# টুলটিতে------টুল
# ট্রফির------ট্রফি
# দুরদানির------দুরদানি
# বিপাকের------বিপাক
# কাছির------কাছি
# আমানতের------আমানত
# অভ্যুত্থানকারীরা------অভ্যুত্থানকারী
# বার্নাব্যুতে------বার্নাব্যু
# পুতাটা------পুতা
# পুতাটি------পুতা
# কূটনীতিককে------কূটনীতিক
# খাদ্যই------খাদ্য
# মর্জিনাকে------মর্জিনা
# চরসিন্দুরে------চরসিন্দুর
# খাদ্যও------খাদ্য
# রাতযাপনের------রাতযাপন
# রাজাদের------রাজাদ
# মিডিয়াকেও------মিডিয়া
# নাট্যশালার------নাট্যশালা
# কসোভোতে------কসোভো
# টুর্নামেন্টেরও------টুর্নামেন্ট
# টেলিস্কোপটিকে------টেলিস্কোপ
# ভাইয়াকে------ভাইয়া
# আফগানিস্তানকে------আফগানিস্তান
# সুপারদের------সুপার
# ইসাকসনের------ইসাকসন
# আশরাফুলকেও------আশরাফুল
# লেখকদিগের------লেখকদিগ
# বেইজিংকে------বেইজিং
# বাণীতে------বাণীত
# অ্যাথলেটের------অ্যাথলেট
# বরকতউল্লাহর------বরক
# জিডিটি------জিডি
# সাবার------সাবা
# ইদ্রিসও------ইদ্রিস
# রাইডারগুলো------রাইডার
# এলজিএসপির------এলজিএসপি
# দিনমজুরের------দিনমজুর
# চারুবাকের------চারুবাক
# ইন্টারফেসের------ইন্টারফেস
# চিকিৎসাকেন্দ্রে------চিকিৎসাকেন্দ্র
# কেইর্নসের------কেইর্নস
# হেডলির------হেডলি
# খরচটা------খরচ
# মেরুতে------মেরু
# ইন্টারফেসেও------ইন্টারফেস
# হোমিওপ্যাথিতে------হোমিওপ্যাথি
# টুনিকে------টুনি
# নিবন্ধনকারীদের------নিবন্ধনকারী
# কাঠিগ্রামের------কাঠিগ্রাম
# মাঠের------মাঠে
# অন্যেরও------অন্য
# অসাম্যের------অসাম্য
# সৈকতেই------সৈকতে
# প্রিয়াঙ্কাকে------প্রিয়াঙ্কা
# কুইংহাইয়ে------কুইংহাই
# কার্যকারিতার------কার্যকারিতা
# সৈকতেও------সৈকত
# সৈকতের------সৈকত
# প্রসিকিউটরদের------প্রসিকিউটর
# কার্যকারিতাও------কার্যকারিতা
# মওকুফে------মওকুফ
# বছিরুনের------বছিরুন
# আজিজকে------আজিজ
# লিখতেই------লিখ
# ভাইয়ারা------ভাইয়া
# উপদ্বীপের------উপদ্বীপ
# কন্যাশিশুরাই------কন্যাশিশু
# কিন্ডারগার্টেনগুলোর------কিন্ডারগার্টেন
# সিনেমাটির------সিনেমাটি
# প্রহরীকেও------প্রহরী
# বালতিতে------বালতি
# মাস্টারকে------মাস্টার
# অরাজকতাকে------অরাজকতা
# কারাফটকে------কারাফট
# মাঠেও------মাঠে
# পেরেজকে------পেরেজ
# থামেলে------থামেল
# গভর্নরই------গভর্ন
# মাঠেই------মাঠে
# সূর্যোদয়ের------সূর্যোদয়
# আগ্রহীদের------আগ্রহী
# ইন্টারফেসটি------ইন্টারফেস
# রবিনের------রবিন
# বৈশিষ্ট্যগুলোর------বৈশিষ্ট্য
# গ্রামগুলোতেও------গ্রাম
# শুভ্রকে------শুভ্র
# ওয়াকওভারের------ওয়াকওভার
# ইপিএসও------ইপিএস
# মূলধারার------মূলধারা
# ইউরোতে------ইউরো
# ভেঙেছেই------ভেঙেছে
# নারীটিও------নারী
# মূলধারায়------মূলধারা
# ইউরোটা------ইউরোটা
# ফ্লোরিডায়ও------ফ্লোরিডা
# মাড়োয়ারিকে------মাড়োয়ারি
# হোয়াইটওয়াশের------হোয়াইটওয়াশ
# সাধারণকেই------সাধারণ
# মানুষটাকে------মানুষ
# নাট্যানুরাগীর------নাট্যানুরাগী
# মিশুকটিকে------মিশুক
# নারীটির------নারী
# লোহম্যানের------লোহম্যান
# কাচটা------কাচ
# ডেসকোর------ডেসকো
# সংখ্যাগরিষ্ঠের------সংখ্যাগরিষ্ঠ
# চাতালে------চাতালে
# মেরুলে------মেরুল
# নুনিয়াছটার------নুনিয়াছ
# প্রস্তুতকারকেরা------প্রস্তুতক
# ওদেরকে------ওদের
# রিকশাভ্যানের------রিকশাভ্যান
# কানাকানির------কানাকানি
# জেরেজেরও------জেরেজ
# চন্দরপলেরও------চন্দরপল
# আইসিসির------আইসিসি
# চন্দরপলেরই------চন্দরপল
# পাইবাসই------পাইবাস
# তত্ত্বাবধানে------তত্ত্বাবধান
# সিএরা------সিএ
# সিএমে------সিএম
# জুতাটির------জুতা
# জেনেশুনেই------জেনেশুন
# সেমিফাইনালগুলো------সেমিফাইনাল
# ভূমিকাতেই------ভূমিকা
# দ্বীপপুঞ্জের------দ্বীপপুঞ্জ
# ফিনল্যান্ডে------ফিনল্যান্ড
# মুরালিধরনেরও------মুরালিধরন
# মিলনদের------মিলন
# মুরালিধরনেরই------মুরালিধরন
# পালপাড়ার------পালপাড়া
# সেচপ্রকল্পকে------সেচপ্রকল্প
# প্রচারমাধ্যমগুলোতে------প্রচারমাধ্যমেষ
# সম্প্রচারমাধ্যমকে------সম্প্রচারমাধ্ম
# আইসিসিও------আইসিসি
# সুবেদারকে------সুবেদার
# ফিনল্যান্ডও------ফিনল্যান্ড
# ফ্লাওয়ারের------ফ্লাওয়ার
# টগরের------টগর
# গুয়াহাটির------গুয়াহা
# স্যারও------স্যার
# কঞ্চিবাড়িতে------কঞ্চিবাড়ি
# স্যারই------স্যার
# পিবিএসে------পিবিএস
# পাঠানোরও------পাঠানো
# ক্যাম্পবেলের------ক্যাম্পবেল
# বিএমবিএর------বিএমবিএ
# সখ্যের------সখ্য
# রাশিয়াতেও------রাশিয়া
# হোসেনেরই------হোসেন
# টেপে------টেপে
# এমএলওর------এমএলও
# রানই------রান
# ন্যায়ের------ন্যায়ের
# শ্রীকৃষ্ণের------শ্রীকৃষ্ণ
# রানও------রান
# পাঠানোকে------পাঠানো
# আশ্রয়কেন্দ্রের------আশ্রয়কেন্দ্র
# রোবোজেলির------রোবোজেলি
# শতাংশকেই------শতাংশ
# মানিকদীতে------মানিকদী
# হ্যাকারদের------হ্যাকার
# সংখ্যাগরিষ্ঠকে------সংখ্যাগরিষ্ঠ
# ঘাটগুলো------ঘাট
# আশ্রয়কেন্দ্রেই------আশ্রয়কেন্দ্র
# স্বাস্থ্যনীতির------স্বাস্থ্যনীতি
# রাতে------রাতে
# ইসহাকের------ইসহাক
# ট্রাইবু্যনালের------ট্রাইব্যেন্ল
# স্বাস্থ্যনীতিই------স্বাস্থ্যন্তি
# বলতেও------বলত
# সোনাদীপার------সোনাদীপার
# টেরও------টের
# নায়লার------নায়লা
# দুষু্বমির------দুষু্বমি
# টেরই------টে
# মাড়োয়ারিরা------মাড়োয়ারি
# এনআরআইতে------এনআরআই
# নকশালপন্থীদের------নকশালপন্থী
# ওভারেও------ওভার
# ডাকাতরা------ডাকাত
# কারুপণ্যে------কারুপণ্য
# ওভারেই------ওভার
# হীরাকে------হীরা
# রানে------রানে
# হোসেনেরও------হোসেন
# ওভারের------ওভার
# হাউসটির------হাউস
# শেরপাদের------শেরপাদ
# চম্পকারই------চম্পকার
# এডিনবরার------এডিনবরা
# সক্ষমতাই------সক্ষমতা
# রাইডারকে------রাইডার
# ভাগ্নেদের------ভাগ্নেদ
# জুরিখে------জুরিখ
# সক্ষমতাও------সক্ষমতা
# আগুয়েরোকে------আগুয়েরো
# শব্দটির------শব্দ
# ছাত্রশিবিরেরটা------ছাত্রশিবির
# তনুময়ের------তনুময়
# শব্দটিও------শব্দ
# শব্দটার------শব্দ
# শব্দটিই------শব্দ
# পালংখালীতে------পালংখালী
# শব্দটাও------শব্দ
# লালনগীতির------লালনগীতি
# চেসের------চেস
# রাতই------রাত
# আদর্শকে------আদর্শক
# সক্ষমতার------সক্ষমতা
# রাতও------রাত
# মেরিকে------মেরি
# মিশনারিরা------মিশনারি
# কোম্পানিকেও------কোম্পানি
# পাবনায়ও------পাবনা
# র‌্যাবের------র‌্যাব
# কোম্পানিকেই------কোম্পানি
# খাজানগরের------খাজানগর
# নিভৃতে------নিভৃত
# কনসোলটিকে------কনসোল
# মোহাম্মদের------মোহাম্ম
# ডাকাতের------ডাকাত
# স্বাধীনতাকামীরাও------স্বাধীনতাকা
# আফগানিস্তানেও------আফগানিস্তান
# সাপের------সাপ
# মৎস্যজীবীরা------মৎস্যজীবী
# দীপ্রটা------দীপ্র
# আফগানিস্তানের------আফগানিস্তান
# চ্যালেঞ্জেও------চ্যালেঞ্জ
# দর্শকেরাও------দর্শকে
# মেডিয়েটরের------মেডিয়েটর
# পতাকাটিও------পতাকা
# আফগানিস্তানেই------আফগানিস্তান
# চ্যালেঞ্জের------চ্যালেঞ্জ
# নীরবতাও------নীরবতা
# আজিজের------আজিজ
# সৈকতকে------সৈকত
# নীরবতাই------নীরবতা
# নূনের------নূন
# লেম্যানকে------লেম্যান
# নীরবতায়------নীরবতা
# গুদামটিকে------গুদাম
# রিকশাচিত্রের------রিকশাচিত্র
# অ্যাথলেটকে------অ্যাথলেট
# মুলারের------মুলা
# টিয়ারগ্যাসে------টিয়ারগ্যাস
# নীরবতার------নীরবতা
# রাগে------রাগে
# ডাকাতিই------ডাকাতি
# বেইজিংয়ে------বেইজিং
# দেয়ালচিত্রকে------দেয়ালচিত্র
# অনিমেষের------অনিমেষ
# ডাকাতির------ডাকাতি
# সংখ্যাগরিষ্ঠরা------সংখ্যাগরিষ্ঠ
# সিসিসির------সিসিসি
# গম্ভীরেরও------গম্ভীর
# বলতেই------বলতে
# কালকেই------কালকে
# কালকের------কালক
# বাংলাভিশনে------বাংলাভিশন
# ওয়ার্কসপের------ওয়ার্কসপ
# ডালাসে------ডালাস
# পানচাষিরা------পানচাষি
# সমুদ্রদূষণের------সমুদ্রদূষণ
# হীরাটা------হীরা
# হীরাটি------হীরা
# সার্বভৌমত্বই------সার্বভৌমত্ব
# এমএলএর------এমএলএ
# টেকই------টেক
# ঐশীগ্রন্থের------ঐশীগ্রন্থ
# মাইনুদ্দীনের------মাইনুদ্দীন
# শিল্পাঞ্চলে------শিল্পাঞ্চল
# ওয়ান্ডারার্সের------ওয়ান্ডারার্স
# মাস্টাররা------মাস্টার
# ডাচদেরই------ডাচদ
# রবিনকে------রবিন
# দায়গুলো------দায়
# মায়াদিকে------মায়াদি
# এমএমসির------এমএমসি
# পণ্ডিতেরা------পণ্ডিতে
# 88.26

# %% [markdown]
# # Visualize Attention
#
# The next step is visualizing the attention values of the medel during the translation.
#
# To do that, the first step is to locate "attention" layer of the model. The attention layer is the 7th layers of the model (`model.layers[7]`), which is the softmax activation-layer after dot-score. Or we can also simply call `model.get_layer('attention')` as we previously name the layer as "attention".

# %%
layers = model.layers
for l in layers:
    print('%s\tname:%s' % (str(l), l.name))
    
assert(model.layers[7] == model.get_layer('attention'))
# Out:
# <keras.engine.topology.InputLayer object at 0x0000004C909BDA20>	name:input_2
# <keras.engine.topology.InputLayer object at 0x0000004C909BDB00>	name:input_1
# <keras.layers.embeddings.Embedding object at 0x0000004C94FE9A58>	name:embedding_2
# <keras.layers.embeddings.Embedding object at 0x0000004C9264A358>	name:embedding_1
# <keras.layers.recurrent.LSTM object at 0x0000004C94FC0F28>	name:lstm_2
# <keras.layers.recurrent.LSTM object at 0x0000004C9264A320>	name:lstm_1
# <keras.layers.merge.Dot object at 0x0000004C9006DA90>	name:dot_1
# <keras.layers.core.Activation object at 0x0000004C9006DEB8>	name:attention
# <keras.layers.merge.Dot object at 0x0000004C9619CA90>	name:dot_2
# <keras.layers.merge.Concatenate object at 0x0000004C961B5B00>	name:concatenate_1
# <keras.layers.wrappers.TimeDistributed object at 0x0000004C961BFA20>	name:time_distributed_1
# <keras.layers.wrappers.TimeDistributed object at 0x0000004C961E7048>	name:time_distributed_2

# %% [markdown]
# We also need to re-build the model so that it returns the output from the attention layer in addition to the normal output.

# %%
attention_layer = model.get_layer('attention') # or model.layers[7]
attention_model = Model(inputs=model.inputs, outputs=model.outputs + [attention_layer.output])

print(attention_model)
print(attention_model.output_shape)
# Out:
# <keras.engine.training.Model object at 0x0000004CC3E34CF8>
# [(None, 20, 100), (None, 20, 20)]

# %%
# for testing

import matplotlib.font_manager as fm
import matplotlib.pyplot as plt

prop = fm.FontProperties(fname='kalpurush.ttf')
s = "কৃষক জমিতে ধান চাষ করে"
x = 0.2
y = 0.2
plt.text(x, y, s, fontproperties=prop)
plt.show()

# %%
# %matplotlib inline  
import matplotlib
import matplotlib.pyplot as plt
import seaborn

#banglar jonno kon font bhalo hoy oita thik korte hobe
seaborn.set(font=['kalpurush.ttf'], font_scale=3)

def attent_and_generate(text):
    encoder_input = encoding.transform(input_encoding, [text.lower()], 20)
    decoder_input = np.zeros(shape=(len(encoder_input), OUTPUT_LENGTH))
    decoder_input[:,0] = encoding.CHAR_CODE_START
    
    for i in range(1, OUTPUT_LENGTH):
        output, attention = attention_model.predict([encoder_input, decoder_input])
        decoder_input[:,i] = output.argmax(axis=2)[:,i]
        attention_density = attention[0]
        decoded_output = decode(output_decoding, decoder_input[0][1:])
        
    return attention_density, decoded_output


def visualize(text):
    attention_density, katakana = attent_and_generate(text)

    plt.clf()
    plt.figure(figsize=(28,12))
    
    ax = seaborn.heatmap(attention_density[:len(katakana) + 2, : len(text) + 2],
        xticklabels=[w for w in text],
        yticklabels=[w for w in katakana])

    ax.invert_yaxis()
    plt.show()

# %%
visualize('সাদা লাল নীল')
# Out:
# C:\Users\RANA_CSE\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1316: UserWarning: findfont: Font family ['kalpurush.ttf'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
visualize('Utada Hikaruk')
# Out:
# C:\Users\RANA_CSE\Anaconda3\lib\site-packages\matplotlib\font_manager.py:1316: UserWarning: findfont: Font family ['Osaka'] not found. Falling back to DejaVu Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %%
visualize('Harry Potter')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-9181a5add40e> in <module>()
# ----> 1 visualize('Harry Potter')
#
# NameError: name 'visualize' is not defined

# %%
# list all data in history
print(history.history.keys())
# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()
# Out:
# dict_keys(['val_loss', 'val_acc', 'loss', 'acc'])
