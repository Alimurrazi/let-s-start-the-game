# %%
from __future__ import print_function

from keras.models import Model
from keras.layers import Input, LSTM, Dense
import matplotlib.pyplot as plt
import numpy as np

batch_size = 64  # Batch size for training.
epochs = 100  # Number of epochs to train for.
latent_dim = 256  # Latent dimensionality of the encoding space.
num_samples = 10000  # Number of samples to train on.
# Path to the data txt file on disk.
data_path = 'fra-eng/fra.txt'
# Out:
# Using TensorFlow backend.

# %%
# Vectorize the data.
input_texts = []
target_texts = []
input_characters = set()
target_characters = set()
with open(data_path, 'r', encoding='utf-8') as f:
    lines = f.read().split('\n')
for line in lines[: min(num_samples, len(lines) - 1)]:
    input_text, target_text = line.split(' ')
    # We use space(' ') as the "start sequence" character
    # for the targets, and "\n" as "end sequence" character.
    target_text = ' ' + target_text + '\n'
    input_texts.append(input_text)
    target_texts.append(target_text)
    for char in input_text:
        if char not in input_characters:
            input_characters.add(char)
    for char in target_text:
        if char not in target_characters:
            target_characters.add(char)

input_characters = sorted(list(input_characters))
target_characters = sorted(list(target_characters))
num_encoder_tokens = len(input_characters)
num_decoder_tokens = len(target_characters)
max_encoder_seq_length = max([len(txt) for txt in input_texts])
max_decoder_seq_length = max([len(txt) for txt in target_texts])

print('Number of samples:', len(input_texts))
print('Number of unique input tokens:', num_encoder_tokens)
print('Number of unique output tokens:', num_decoder_tokens)
print('Max sequence length for inputs:', max_encoder_seq_length)
print('Max sequence length for outputs:', max_decoder_seq_length)
# Out:
# Number of samples: 10000
# Number of unique input tokens: 66
# Number of unique output tokens: 67
# Max sequence length for inputs: 20
# Max sequence length for outputs: 20

# %%
input_token_index = dict(
    [(char, i) for i, char in enumerate(input_characters)])
target_token_index = dict(
    [(char, i) for i, char in enumerate(target_characters)])

encoder_input_data = np.zeros(
    (len(input_texts), max_encoder_seq_length, num_encoder_tokens),
    dtype='float32')
decoder_input_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens),
    dtype='float32')
decoder_target_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens),
    dtype='float32')

for i, (input_text, target_text) in enumerate(zip(input_texts, target_texts)):
    for t, char in enumerate(input_text):
        encoder_input_data[i, t, input_token_index[char]] = 1.
    for t, char in enumerate(target_text):
        # decoder_target_data is ahead of decoder_input_data by one timestep
        decoder_input_data[i, t, target_token_index[char]] = 1.
        if t > 0:
            # decoder_target_data will be ahead by one timestep
            # and will not include the start character.
            decoder_target_data[i, t - 1, target_token_index[char]] = 1.

# %%
# Define an input sequence and process it.
encoder_inputs = Input(shape=(None, num_encoder_tokens))
encoder = LSTM(latent_dim, return_state=True)
encoder_outputs, state_h, state_c = encoder(encoder_inputs)
# We discard `encoder_outputs` and only keep the states.
encoder_states = [state_h, state_c]

# Set up the decoder, using `encoder_states` as initial state.
decoder_inputs = Input(shape=(None, num_decoder_tokens))
# We set up our decoder to return full output sequences,
# and to return internal states as well. We don't use the
# return states in the training model, but we will use them in inference.
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_inputs,
                                     initial_state=encoder_states)
decoder_dense = Dense(num_decoder_tokens, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

# %%
# Define the model that will turn
# `encoder_input_data` & `decoder_input_data` into `decoder_target_data`
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

# Run training
model.compile(optimizer='rmsprop', loss='categorical_crossentropy')
model.fit([encoder_input_data, decoder_input_data], decoder_target_data,
          batch_size=batch_size,
          epochs=epochs,
          validation_split=0.2)
# Save model
model.save('s2s.h5')

# Next: inference mode (sampling).
# Here's the drill:
# 1) encode input and retrieve initial decoder state
# 2) run one step of decoder with this initial state
# and a "start of sequence" token as target.
# Output will be the next target token
# 3) Repeat with the current target token and current states

# Define sampling models
encoder_model = Model(encoder_inputs, encoder_states)

decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
decoder_outputs, state_h, state_c = decoder_lstm(
    decoder_inputs, initial_state=decoder_states_inputs)
decoder_states = [state_h, state_c]
decoder_outputs = decoder_dense(decoder_outputs)
decoder_model = Model(
    [decoder_inputs] + decoder_states_inputs,
    [decoder_outputs] + decoder_states)

# Reverse-lookup token index to decode sequences back to
# something readable.
reverse_input_char_index = dict(
    (i, char) for char, i in input_token_index.items())
reverse_target_char_index = dict(
    (i, char) for char, i in target_token_index.items())
# Out:
# Train on 8000 samples, validate on 2000 samples
# Epoch 1/100
# 8000/8000 [==============================] - 43s 5ms/step - loss: 1.1929 - val_loss: 1.1272
# Epoch 2/100
# 8000/8000 [==============================] - 43s 5ms/step - loss: 1.0878 - val_loss: 1.0557
# Epoch 3/100
# 8000/8000 [==============================] - 42s 5ms/step - loss: 0.9858 - val_loss: 0.9429
# Epoch 4/100
# 8000/8000 [==============================] - 42s 5ms/step - loss: 0.9164 - val_loss: 0.9033
# Epoch 5/100
# 8000/8000 [==============================] - 41s 5ms/step - loss: 0.8649 - val_loss: 0.8666
# Epoch 6/100
# 8000/8000 [==============================] - 41s 5ms/step - loss: 0.8184 - val_loss: 0.8070
# Epoch 7/100
# 8000/8000 [==============================] - 43s 5ms/step - loss: 0.7535 - val_loss: 0.7397
# Epoch 8/100
# 8000/8000 [==============================] - 40s 5ms/step - loss: 0.6869 - val_loss: 0.7031
# Epoch 9/100
# 8000/8000 [==============================] - 41s 5ms/step - loss: 0.6345 - val_loss: 0.6654
# Epoch 10/100
# 8000/8000 [==============================] - 41s 5ms/step - loss: 0.5807 - val_loss: 0.6257
# Epoch 11/100
# 8000/8000 [==============================] - 39s 5ms/step - loss: 0.5329 - val_loss: 0.5813
# Epoch 12/100
# 8000/8000 [==============================] - 41s 5ms/step - loss: 0.4861 - val_loss: 0.5569
# Epoch 13/100
# 8000/8000 [==============================] - 42s 5ms/step - loss: 0.4369 - val_loss: 0.4977
# Epoch 14/100
# 8000/8000 [==============================] - 40s 5ms/step - loss: 0.3919 - val_loss: 0.4829
# Epoch 15/100
# 8000/8000 [==============================] - 41s 5ms/step - loss: 0.3527 - val_loss: 0.4456
# Epoch 16/100
# 8000/8000 [==============================] - 40s 5ms/step - loss: 0.3158 - val_loss: 0.4183
# Epoch 17/100
# 8000/8000 [==============================] - 41s 5ms/step - loss: 0.2810 - val_loss: 0.3859
# Epoch 18/100
# 8000/8000 [==============================] - 41s 5ms/step - loss: 0.2503 - val_loss: 0.4086
# Epoch 19/100
# 8000/8000 [==============================] - 41s 5ms/step - loss: 0.2207 - val_loss: 0.3533
# Epoch 20/100
# 8000/8000 [==============================] - 41s 5ms/step - loss: 0.1954 - val_loss: 0.3419
# Epoch 21/100
# 8000/8000 [==============================] - 39s 5ms/step - loss: 0.1741 - val_loss: 0.3265
# Epoch 22/100
# 8000/8000 [==============================] - 39s 5ms/step - loss: 0.1529 - val_loss: 0.3076
# Epoch 23/100
# 8000/8000 [==============================] - 40s 5ms/step - loss: 0.1344 - val_loss: 0.3012
# Epoch 24/100
# 8000/8000 [==============================] - 40s 5ms/step - loss: 0.1192 - val_loss: 0.2894
# Epoch 25/100
# 8000/8000 [==============================] - 41s 5ms/step - loss: 0.1047 - val_loss: 0.2788
# Epoch 26/100
# 8000/8000 [==============================] - 40s 5ms/step - loss: 0.0935 - val_loss: 0.2897
# Epoch 27/100
# 8000/8000 [==============================] - 40s 5ms/step - loss: 0.0818 - val_loss: 0.2592
# Epoch 28/100
# 8000/8000 [==============================] - 37s 5ms/step - loss: 0.0724 - val_loss: 0.2669
# Epoch 29/100
# 8000/8000 [==============================] - 40s 5ms/step - loss: 0.0643 - val_loss: 0.2667
# Epoch 30/100
# 8000/8000 [==============================] - 42s 5ms/step - loss: 0.0576 - val_loss: 0.2611
# Epoch 31/100
# 8000/8000 [==============================] - 38s 5ms/step - loss: 0.0507 - val_loss: 0.2754
# Epoch 32/100
# 8000/8000 [==============================] - 38s 5ms/step - loss: 0.0461 - val_loss: 0.2577
# Epoch 33/100
# 8000/8000 [==============================] - 39s 5ms/step - loss: 0.0410 - val_loss: 0.2674
# Epoch 34/100
# 8000/8000 [==============================] - 38s 5ms/step - loss: 0.0382 - val_loss: 0.2584
# Epoch 35/100
# 8000/8000 [==============================] - 42s 5ms/step - loss: 0.0341 - val_loss: 0.2548
# Epoch 36/100
# 8000/8000 [==============================] - 38s 5ms/step - loss: 0.0308 - val_loss: 0.2624
# Epoch 37/100
# 8000/8000 [==============================] - 37s 5ms/step - loss: 0.0287 - val_loss: 0.2564
# Epoch 38/100
# 8000/8000 [==============================] - 37s 5ms/step - loss: 0.0270 - val_loss: 0.2718
# Epoch 39/100
# 8000/8000 [==============================] - 37s 5ms/step - loss: 0.0243 - val_loss: 0.2579
# Epoch 40/100
# 8000/8000 [==============================] - 37s 5ms/step - loss: 0.0231 - val_loss: 0.2754
# Epoch 41/100
# 8000/8000 [==============================] - 38s 5ms/step - loss: 0.0206 - val_loss: 0.2564
# Epoch 42/100
# 8000/8000 [==============================] - 37s 5ms/step - loss: 0.0196 - val_loss: 0.2606
# Epoch 43/100
# 8000/8000 [==============================] - 38s 5ms/step - loss: 0.0182 - val_loss: 0.2755
# Epoch 44/100
# 8000/8000 [==============================] - 37s 5ms/step - loss: 0.0178 - val_loss: 0.2611
# Epoch 45/100
# 8000/8000 [==============================] - 39s 5ms/step - loss: 0.0159 - val_loss: 0.2606
# Epoch 46/100
# 8000/8000 [==============================] - 39s 5ms/step - loss: 0.0167 - val_loss: 0.2623
# Epoch 47/100
# 8000/8000 [==============================] - 38s 5ms/step - loss: 0.0145 - val_loss: 0.2605
# Epoch 48/100
# 8000/8000 [==============================] - 38s 5ms/step - loss: 0.0142 - val_loss: 0.2673
# Epoch 49/100
# 8000/8000 [==============================] - 37s 5ms/step - loss: 0.0122 - val_loss: 0.2588
# Epoch 50/100
# 8000/8000 [==============================] - 38s 5ms/step - loss: 0.0128 - val_loss: 0.2547
# Epoch 51/100
# 8000/8000 [==============================] - 40s 5ms/step - loss: 0.0119 - val_loss: 0.2578
# Epoch 52/100
# 8000/8000 [==============================] - 38s 5ms/step - loss: 0.0116 - val_loss: 0.2672
# Epoch 53/100
# 8000/8000 [==============================] - 37s 5ms/step - loss: 0.0117 - val_loss: 0.2586
# Epoch 54/100
# 8000/8000 [==============================] - 38s 5ms/step - loss: 0.0099 - val_loss: 0.2620
# Epoch 55/100
# 8000/8000 [==============================] - 40s 5ms/step - loss: 0.0107 - val_loss: 0.2641
# Epoch 56/100
# 8000/8000 [==============================] - 40s 5ms/step - loss: 0.0099 - val_loss: 0.2641
# Epoch 57/100
# 8000/8000 [==============================] - 42s 5ms/step - loss: 0.0095 - val_loss: 0.2771
# Epoch 58/100
# 8000/8000 [==============================] - 41s 5ms/step - loss: 0.0089 - val_loss: 0.2731
# Epoch 59/100
# 8000/8000 [==============================] - 37s 5ms/step - loss: 0.0089 - val_loss: 0.2719
# Epoch 60/100
# 8000/8000 [==============================] - 39s 5ms/step - loss: 0.0081 - val_loss: 0.2653
# Epoch 61/100
# 8000/8000 [==============================] - 44s 6ms/step - loss: 0.0085 - val_loss: 0.2639
# Epoch 62/100
# 8000/8000 [==============================] - 45s 6ms/step - loss: 0.0081 - val_loss: 0.2618
# Epoch 63/100
# 8000/8000 [==============================] - 45s 6ms/step - loss: 0.0075 - val_loss: 0.2901
# Epoch 64/100
# 8000/8000 [==============================] - 43s 5ms/step - loss: 0.0073 - val_loss: 0.2801
# Epoch 65/100
# 8000/8000 [==============================] - 41s 5ms/step - loss: 0.0078 - val_loss: 0.2704
# Epoch 66/100
# 8000/8000 [==============================] - 40s 5ms/step - loss: 0.0075 - val_loss: 0.2675
# Epoch 67/100
# 8000/8000 [==============================] - 40s 5ms/step - loss: 0.0065 - val_loss: 0.2648
# Epoch 68/100
# 8000/8000 [==============================] - 41s 5ms/step - loss: 0.0066 - val_loss: 0.2621
# Epoch 69/100
# 8000/8000 [==============================] - 44s 5ms/step - loss: 0.0067 - val_loss: 0.2766
# Epoch 70/100
# 8000/8000 [==============================] - 43s 5ms/step - loss: 0.0065 - val_loss: 0.2816
# Epoch 71/100
# 8000/8000 [==============================] - 42s 5ms/step - loss: 0.0061 - val_loss: 0.2768
# Epoch 72/100
# 8000/8000 [==============================] - 43s 5ms/step - loss: 0.0064 - val_loss: 0.2769
# Epoch 73/100
# 8000/8000 [==============================] - 42s 5ms/step - loss: 0.0059 - val_loss: 0.2724
# Epoch 74/100
# 8000/8000 [==============================] - 40s 5ms/step - loss: 0.0059 - val_loss: 0.2617
# Epoch 75/100
# 8000/8000 [==============================] - 44s 6ms/step - loss: 0.0056 - val_loss: 0.2631
# Epoch 76/100
# 8000/8000 [==============================] - 44s 5ms/step - loss: 0.0058 - val_loss: 0.2860
# Epoch 77/100
# 8000/8000 [==============================] - 43s 5ms/step - loss: 0.0053 - val_loss: 0.2811
# Epoch 78/100
# 8000/8000 [==============================] - 44s 5ms/step - loss: 0.0054 - val_loss: 0.2696
# Epoch 79/100
# 8000/8000 [==============================] - 37s 5ms/step - loss: 0.0050 - val_loss: 0.2797
# Epoch 80/100
# 8000/8000 [==============================] - 37s 5ms/step - loss: 0.0054 - val_loss: 0.2778
# Epoch 81/100
# 8000/8000 [==============================] - 41s 5ms/step - loss: 0.0053 - val_loss: 0.2719
# Epoch 82/100
# 8000/8000 [==============================] - 38s 5ms/step - loss: 0.0053 - val_loss: 0.2718
# Epoch 83/100
# 8000/8000 [==============================] - 37s 5ms/step - loss: 0.0047 - val_loss: 0.2736
# Epoch 84/100
# 8000/8000 [==============================] - 39s 5ms/step - loss: 0.0049 - val_loss: 0.2811
# Epoch 85/100
# 8000/8000 [==============================] - 38s 5ms/step - loss: 0.0049 - val_loss: 0.2707
# Epoch 86/100
# 8000/8000 [==============================] - 39s 5ms/step - loss: 0.0048 - val_loss: 0.2685
# Epoch 87/100
# 8000/8000 [==============================] - 39s 5ms/step - loss: 0.0044 - val_loss: 0.2835
# Epoch 88/100
# 8000/8000 [==============================] - 39s 5ms/step - loss: 0.0045 - val_loss: 0.2705
# Epoch 89/100
# 8000/8000 [==============================] - 40s 5ms/step - loss: 0.0045 - val_loss: 0.2686
# Epoch 90/100
# 8000/8000 [==============================] - 39s 5ms/step - loss: 0.0042 - val_loss: 0.2722
# Epoch 91/100
# 8000/8000 [==============================] - 38s 5ms/step - loss: 0.0040 - val_loss: 0.2746
# Epoch 92/100
# 8000/8000 [==============================] - 40s 5ms/step - loss: 0.0040 - val_loss: 0.2714
# Epoch 93/100
# 8000/8000 [==============================] - 40s 5ms/step - loss: 0.0042 - val_loss: 0.2692
# Epoch 94/100
# 8000/8000 [==============================] - 40s 5ms/step - loss: 0.0039 - val_loss: 0.2695
# Epoch 95/100
# 8000/8000 [==============================] - 40s 5ms/step - loss: 0.0042 - val_loss: 0.2712
# Epoch 96/100
# 8000/8000 [==============================] - 39s 5ms/step - loss: 0.0038 - val_loss: 0.2752
# Epoch 97/100
# 8000/8000 [==============================] - 38s 5ms/step - loss: 0.0035 - val_loss: 0.2834
# Epoch 98/100
# 8000/8000 [==============================] - 38s 5ms/step - loss: 0.0038 - val_loss: 0.2722
# Epoch 99/100
# 8000/8000 [==============================] - 37s 5ms/step - loss: 0.0039 - val_loss: 0.2789
# Epoch 100/100
# 8000/8000 [==============================] - 38s 5ms/step - loss: 0.0041 - val_loss: 0.2795
# C:\Users\RANA_CSE\Anaconda3\lib\site-packages\keras\engine\topology.py:2361: UserWarning: Layer lstm_2 was passed non-serializable keyword arguments: {'initial_state': [<tf.Tensor 'lstm_1/while/Exit_2:0' shape=(?, 256) dtype=float32>, <tf.Tensor 'lstm_1/while/Exit_3:0' shape=(?, 256) dtype=float32>]}. They will not be included in the serialized model (and thus will be missing at deserialization time).
#   str(node.arguments) + '. They will not be included '

# %%
def decode_sequence(input_seq):
    # Encode the input as state vectors.
    states_value = encoder_model.predict(input_seq)

    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1, 1, num_decoder_tokens))
    # Populate the first character of target sequence with the start character.
    target_seq[0, 0, target_token_index[' ']] = 1.

    # Sampling loop for a batch of sequences
    # (to simplify, here we assume a batch of size 1).
    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict(
            [target_seq] + states_value)

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_char = reverse_target_char_index[sampled_token_index]
        decoded_sentence += sampled_char

        # Exit condition: either hit max length
        # or find stop character.
        if (sampled_char == '\n' or
           len(decoded_sentence) > max_decoder_seq_length):
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1, 1, num_decoder_tokens))
        target_seq[0, 0, sampled_token_index] = 1.

        # Update states
        states_value = [h, c]

    return decoded_sentence


for seq_index in range(100):
    # Take one sequence (part of the training set)
    # for trying out decoding.
    input_seq = encoder_input_data[seq_index: seq_index + 1]
    decoded_sentence = decode_sequence(input_seq)
    print('-')
    print('Input sentence:', input_texts[seq_index])
    print('Decoded sentence:', decoded_sentence)
# Out:
# -
# Input sentence: ﻿অ্যান্ডেজ
# Decoded sentence: অ্যান্ডেজ
#
# -
# Input sentence: আলমের
# Decoded sentence: আলম
#
# -
# Input sentence: স্পিনিংয়ের
# Decoded sentence: স্পিনিং
#
# -
# Input sentence: জোরদারের
# Decoded sentence: জোরদার
#
# -
# Input sentence: ঘড়িতে
# Decoded sentence: ঘড়ি
#
# -
# Input sentence: ডেনিমেরও
# Decoded sentence: ডেনিম
#
# -
# Input sentence: বেবিট্যাক্সিই
# Decoded sentence: বেবিট্যাক্সি
#
# -
# Input sentence: বাড়িটিতে
# Decoded sentence: বাড়ি
#
# -
# Input sentence: ইনিংসটিতেই
# Decoded sentence: ইনিংস
#
# -
# Input sentence: মার্কনিকে
# Decoded sentence: মার্কিনি
#
# -
# Input sentence: ড্রাইয়ারের
# Decoded sentence: ড্রাইয়ার
#
# -
# Input sentence: পুরোহিতদের
# Decoded sentence: পুরোহিত
#
# -
# Input sentence: অভিবাসীর
# Decoded sentence: অভিবাসী
#
# -
# Input sentence: অ্যালামনাইদের
# Decoded sentence: অ্যালামনাই
#
# -
# Input sentence: সুইসপোস্টের
# Decoded sentence: সুইসপোস্টে
#
# -
# Input sentence: দেয়ালঘড়ির
# Decoded sentence: দেয়ালঘড়ি
#
# -
# Input sentence: প্রাণরসায়নে
# Decoded sentence: প্রারসণায়ন
#
# -
# Input sentence: ছক্কাটি
# Decoded sentence: ছক্কা
#
# -
# Input sentence: গানবাজনার
# Decoded sentence: গানবাজনা
#
# -
# Input sentence: ঘড়িটা
# Decoded sentence: ঘড়ি
#
# -
# Input sentence: ঘড়িটি
# Decoded sentence: ঘড়ি
#
# -
# Input sentence: ছক্কাটা
# Decoded sentence: ছক্কা
#
# -
# Input sentence: গোবরের
# Decoded sentence: গোবর
#
# -
# Input sentence: হেরাতে
# Decoded sentence: হেরাত
#
# -
# Input sentence: বসুরও
# Decoded sentence: বসু
#
# -
# Input sentence: কুপনটি
# Decoded sentence: কুপন
#
# -
# Input sentence: বসুরই
# Decoded sentence: বসু
#
# -
# Input sentence: দলীয়করণকে
# Decoded sentence: দলীয়করণ
#
# -
# Input sentence: লেওনার্দোর
# Decoded sentence: লেওনার্দো
#
# -
# Input sentence: ধমকটি
# Decoded sentence: ধমক
#
# -
# Input sentence: সম্পর্কটাকে
# Decoded sentence: সম্প্রকর
#
# -
# Input sentence: নির্দেশের
# Decoded sentence: নির্দেশ
#
# -
# Input sentence: লেওনার্দোই
# Decoded sentence: লেওনার্দো
#
# -
# Input sentence: জল্পনার
# Decoded sentence: জল্পনা
#
# -
# Input sentence: স্পন্সরদের
# Decoded sentence: স্পন্সর
#
# -
# Input sentence: কোকিলও
# Decoded sentence: কোকিল
#
# -
# Input sentence: ইয়াসমিনের
# Decoded sentence: ইয়াসমিন
#
# -
# Input sentence: রঞ্জনের
# Decoded sentence: রঞ্জন
#
# -
# Input sentence: বয়াতির
# Decoded sentence: বয়াতি
#
# -
# Input sentence: কবিতাগুচ্ছ
# Decoded sentence: কবিতা
#
# -
# Input sentence: অ্যাডফেস্টে
# Decoded sentence: অ্যাডফেস্ট
#
# -
# Input sentence: দেনদরবারের
# Decoded sentence: দেনদরবার
#
# -
# Input sentence: হকিংয়ের
# Decoded sentence: হকিং
#
# -
# Input sentence: নির্দেশেই
# Decoded sentence: নির্দেশ
#
# -
# Input sentence: নির্দেশেও
# Decoded sentence: নির্দেশ
#
# -
# Input sentence: জ্যাজের
# Decoded sentence: জ্যাজ
#
# -
# Input sentence: ডাকাতদের
# Decoded sentence: ডাকাত
#
# -
# Input sentence: স্মৃতিস্মারকের
# Decoded sentence: স্মৃতিস্মারক
#
# -
# Input sentence: শিবলুকে
# Decoded sentence: শিবলু
#
# -
# Input sentence: কম্পিউটিংয়ের
# Decoded sentence: কম্পিউটিং
#
# -
# Input sentence: ক্যাশিয়ারের
# Decoded sentence: ক্যাশিয়ার
#
# -
# Input sentence: লেন্সটিকে
# Decoded sentence: লেন্স
#
# -
# Input sentence: সিমবিয়ানে
# Decoded sentence: সিমবিয়ান
#
# -
# Input sentence: খুনে
# Decoded sentence: খুন
#
# -
# Input sentence: বার্কের
# Decoded sentence: বার্ক
#
# -
# Input sentence: বাড়িটিকে
# Decoded sentence: বাড়ি
#
# -
# Input sentence: ইনকরপোরেশনের
# Decoded sentence: ইনকরপোরেশন
#
# -
# Input sentence: খেজুরগুলো
# Decoded sentence: খেজুর
#
# -
# Input sentence: বৃদ্ধিতে
# Decoded sentence: বৃদ্ধি
#
# -
# Input sentence: খুনই
# Decoded sentence: খুন
#
# -
# Input sentence: গল্পটাকে
# Decoded sentence: গল্প
#
# -
# Input sentence: পরমাণুবিজ্ঞানীর
# Decoded sentence: পরমাণুবিজ্ঞানী
#
# -
# Input sentence: খুনও
# Decoded sentence: খুন
#
# -
# Input sentence: কিডনিগুলো
# Decoded sentence: কিডনি
#
# -
# Input sentence: সদরে
# Decoded sentence: সদর
#
# -
# Input sentence: তৃণভূমির
# Decoded sentence: তৃণভূমি
#
# -
# Input sentence: উদ্বাস্তুরা
# Decoded sentence: উদ্বাস্তু
#
# -
# Input sentence: ডিকশনারির
# Decoded sentence: ডিকশনারি
#
# -
# Input sentence: গণ্ডির
# Decoded sentence: গণ্ডিড
#
# -
# Input sentence: কিছুরই
# Decoded sentence: কিছু
#
# -
# Input sentence: ভ্রমণকারীর
# Decoded sentence: ভ্রমণকারী
#
# -
# Input sentence: জ্ঞানকেন্দ্রটি
# Decoded sentence: জ্ঞানকেন্দ্র
#
# -
# Input sentence: ভোক্তাদের
# Decoded sentence: ভোক্তা
#
# -
# Input sentence: হইলে
# Decoded sentence: হইল
#
# -
# Input sentence: হারেছের
# Decoded sentence: হারেছ
#
# -
# Input sentence: জুটিটার
# Decoded sentence: জুটি
#
# -
# Input sentence: বজ্রপাতের
# Decoded sentence: বজ্রপাত
#
# -
# Input sentence: সাংবাদিকেরা
# Decoded sentence: সাংবাদিকা
#
# -
# Input sentence: মামলাজটের
# Decoded sentence: মামলাজট
#
# -
# Input sentence: নির্বাপণযন্ত্রও
# Decoded sentence: নির্বাপণযন্ত্র
#
# -
# Input sentence: আলিঙ্গনের
# Decoded sentence: আলিঙ্গন
#
# -
# Input sentence: সাজাদপুরের
# Decoded sentence: সাজাদপুর
#
# -
# Input sentence: খুবই
# Decoded sentence: খুব
#
# -
# Input sentence: জুটিটির
# Decoded sentence: জুটি
#
# -
# Input sentence: পদায়নে
# Decoded sentence: পদায়ন
#
# -
# Input sentence: পেট্রোলের
# Decoded sentence: পেট্রোল
#
# -
# Input sentence: হইতে
# Decoded sentence: হইত
#
# -
# Input sentence: স্পোর্তোও
# Decoded sentence: স্পোর্তো
#
# -
# Input sentence: এক্সচেঞ্জগুলোর
# Decoded sentence: এক্সচেঞ্জ
#
# -
# Input sentence: শাখাওয়াতের
# Decoded sentence: শাখাওয়াত
#
# -
# Input sentence: শরীফকেও
# Decoded sentence: শরীফ
#
# -
# Input sentence: বাস্তুসংস্থানে
# Decoded sentence: বাস্তুসংস্থান
#
# -
# Input sentence: ছেলেরাই
# Decoded sentence: ছেলে
#
# -
# Input sentence: চৌধুরীপাড়ায়
# Decoded sentence: চৌধুরীপাড়া
#
# -
# Input sentence: জুটিটাও
# Decoded sentence: জুটি
#
# -
# Input sentence: জুটিটাই
# Decoded sentence: জুটি
#
# -
# Input sentence: মাত্তেওকে
# Decoded sentence: মাত্তেও
#
# -
# Input sentence: ছেলেরাও
# Decoded sentence: ছেলে
#
# -
# Input sentence: মাশরুবার
# Decoded sentence: মাশরুবা
#
# -
# Input sentence: পাকিস্তানিদেরও
# Decoded sentence: পাকিস্তানি
